# %% [markdown]
# ## Imports

# %% [markdown]
# ### Imports

# %%
import random, gensim, nltk, re, json, os, torch, time, pickle
import numpy as np
import pandas as pd
import networkx as nx
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import scipy.sparse as sp
import plotly.graph_objects as go
from pandarallel import pandarallel
from math import exp
from multiprocessing import Process
from multiprocessing import Manager
from statistics import mode, mean, stdev
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import WordNetLemmatizer
from typing import Dict, Tuple, Sequence, Any, List, Set, Union, Collection, Optional
from sklearn import metrics
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, MeanShift, DBSCAN
from sklearn.metrics import recall_score, f1_score, precision_score, accuracy_score, roc_auc_score, average_precision_score
from collections import defaultdict, Counter

# %% [markdown]
# ## Defined Functions

# %% [markdown]
# ### PID

# %%
class PIDControl():
    """docstring for ClassName"""

    def __init__(self, Kp=0.001, Ki=-0.001):
        """define them out of loop"""
        # self.exp_KL = exp_KL
        self.I_k1 = 0.0
        self.W_k1 = 0.0
        self.e_k1 = 0.0
        self.Kp = Kp
        self.Ki = Ki

    def _Kp_fun(self, Err, scale=1):
        return 1.0 / (1.0 + float(scale) * exp(Err))

    def pid(self, exp_KL, KL_loss):
        """
     position PID algorithm
     Input: KL_loss
     return: weight for KL loss, beta
     """
        error_k = exp_KL - KL_loss
        ## comput U as the control factor
        Pk = self.Kp * self._Kp_fun(error_k)
        Ik = self.I_k1 + self.Ki * error_k
        # Dk = (error_k - self.e_k1) * Kd

        ## window up for integrator
        if self.W_k1 < 0 and self.W_k1 >= 1:
            Ik = self.I_k1

        Wk = Pk + Ik
        self.W_k1 = Wk
        self.I_k1 = Ik
        self.e_k1 = error_k

        ## min and max value
        if Wk >= 1:
            Wk = 1.0
        if Wk < 0:
            Wk = 0.0

        return Wk

# %% [markdown]
# ### Discriminator

# %%
def kaiming_init(m):
    if isinstance(m, (nn.Linear, nn.Conv2d)):
        init.kaiming_normal_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0)
    elif isinstance(m, (nn.BatchNorm1d, nn.BatchNorm2d)):
        m.weight.data.fill_(1)
        if m.bias is not None:
            m.bias.data.fill_(0)

# %%
def normal_init(m):
    if isinstance(m, (nn.Linear, nn.Conv2d)):
        init.normal_(m.weight, 0, 0.02)
        if m.bias is not None:
            m.bias.data.fill_(0)
    elif isinstance(m, (nn.BatchNorm1d, nn.BatchNorm2d)):
        m.weight.data.fill_(1)
        if m.bias is not None:
            m.bias.data.fill_(0)

# %%
class Discriminator(nn.Module):
    def __init__(self, z_dim):
        super(Discriminator, self).__init__()
        self.z_dim = z_dim
        self.net = nn.Sequential(
            nn.Linear(z_dim, 1000),
            nn.LeakyReLU(0.2, True),
            nn.Linear(1000, 1000),
            nn.LeakyReLU(0.2, True),
            nn.Linear(1000, 2),
        )
        self.weight_init()

    def weight_init(self, mode='normal'):
        if mode == 'kaiming':
            initializer = kaiming_init
        elif mode == 'normal':
            initializer = normal_init

        for block in self._modules:
            for m in self._modules[block]:
                initializer(m)

    def forward(self, z):
        return self.net(z).squeeze()

# %% [markdown]
# ### Model

# %%
def glorot_init(input_dim, output_dim):
    init_range = np.sqrt(6.0 / (input_dim + output_dim))
    initial = torch.rand(input_dim, output_dim) * 2 * init_range - init_range
    return nn.Parameter(initial)

# %%
class GraphConvSparse(nn.Module):
    def __init__(self, input_dim, output_dim, adj, activation=F.relu, **kwargs):
        super(GraphConvSparse, self).__init__(**kwargs)
        self.weight = glorot_init(input_dim, output_dim)
        self.adj = adj
        self.activation = activation

    def forward(self, inputs):
        x = inputs
        x = torch.mm(x, self.weight)
        x = torch.mm(self.adj, x)
        outputs = self.activation(x)
        return outputs

# %%
class InfoVGAE(nn.Module):
    def __init__(self, args, adj):
        super(InfoVGAE, self).__init__()
        self.input_dim = args.input_dim
        self.adj_matrix = adj
        self.hidden1_dim = args.hidden1_dim
        self.hidden2_dim = args.hidden2_dim
        self.base_gcn = GraphConvSparse(self.input_dim, self.hidden1_dim, adj, activation=F.relu)
        self.gcn_mean = GraphConvSparse(self.hidden1_dim, self.hidden2_dim, adj, activation=lambda x: x)
        self.gcn_logstddev = GraphConvSparse(self.hidden1_dim, self.hidden2_dim, adj, activation=lambda x: x)
        self.args = args

        assert args.num_user is not None
        assert args.num_assertion is not None
        self.num_user = args.num_user
        self.num_assertion = args.num_assertion
        self.user_nodes_mask = torch.zeros((self.num_user + self.num_assertion, self.hidden2_dim))
        self.user_nodes_mask[:self.num_user, :] = 1.0
        self.asser_nodes_mask = torch.zeros((self.num_user + self.num_assertion, self.hidden2_dim))
        self.asser_nodes_mask[self.num_user:, :] = 1.0
        if self.args.use_cuda:
            self.user_nodes_mask = self.user_nodes_mask.cuda()
            self.asser_nodes_mask = self.asser_nodes_mask.cuda()

    def encode(self, x):
        hidden = self.base_gcn(x)
        self.mean = self.gcn_mean(hidden)
        self.logstd = self.gcn_logstddev(hidden)
        gaussian_noise = torch.randn(x.size(0), self.hidden2_dim).cuda() if self.args.use_cuda else torch.randn(x.size(0), self.hidden2_dim)
        sampled_z = F.relu(gaussian_noise * torch.exp(self.logstd) + self.mean)
        return sampled_z

    def encode_normal(self, x):
        hidden = self.base_gcn(x)
        self.mean = self.gcn_mean(hidden)
        self.logstd = self.gcn_logstddev(hidden)
        gaussian_noise = torch.randn(x.size(0), self.hidden2_dim).cuda() if self.args.use_cuda else torch.randn(x.size(0), self.hidden2_dim)
        sampled_z = gaussian_noise * torch.exp(self.logstd) + self.mean
        return sampled_z

    def decode(self, z):
        return torch.sigmoid(torch.matmul(z, z.t()))

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z)

# %% [markdown]
# ### Feature Builder

# %%
class FeatureBuilderBase():
    def __init__(self):
        self.module_name = "FeatureBuilderBase"

    def initialize(self, params):
        for key, value in params:
            setattr(self, key, value)

    # user-index map: user_name --> i
    def get_user2index(self, data):
        userMap = dict()
        for i, user in enumerate(data.name.unique()):
            userMap[user] = i
        return userMap

    # tweet-index map: tweet_text --> j
    def get_tweet2index(self, data):
        tweetMap = dict()
        for i, tweet in enumerate(data.postTweet.unique()):
            tweetMap[tweet] = i
        return tweetMap

    # construct user-tweet matrix: userTweet[i, j] = cnt
    def get_bimatrix(self, user2index, tweet2index, data):
        userTweet = np.zeros((len(user2index), len(tweet2index)))
        for user, tweet in data[['name', 'postTweet']].iloc[::-1].values:
            userTweet[user2index[user], tweet2index[tweet]] += 1
        return userTweet

# %%
class MFFeatureBuilder(FeatureBuilderBase):
    def __init__(self, processed_data, mode, num_process=40):
        super(MFFeatureBuilder).__init__()
        self.data = processed_data
        self.build_key_matrix(self.data)
        self.mode = mode
        self.num_process = num_process

        self.supporting_modes = ["multiply", "m_smooth"]
        if self.mode not in self.supporting_modes:
            raise NotImplementedError("Only support modes: {}".format(self.supporting_modes))

    # construct keyword list {keywords}
    def get_keywordList(self, data):
        keywordList = []
        for tweet in data.postTweet:
            keywordList += tweet.split()
        keywordList = set(keywordList)
        return keywordList

    # get user-key matrix: user --> keywords count
    def get_user2keywords(self, data, keyword_list, user):
        tempKey = []
        tempCount = dict.fromkeys(keyword_list, 0)
        for tweet in data[data.name == user].postTweet:
            tempKey += tweet.split()

        for word in set(tempKey):
            tempCount[word] = tempKey.count(word)
        return list(tempCount.values())

    # construct user-keyword Matrix: for every user
    def get_users2keywords(self, user2index, data, keyword_list):
        userKey = pd.DataFrame(list(user2index.keys()), columns=['name'])
        tic = time.time()
        userKey['dist'] = userKey.name.parallel_apply(lambda x: self.get_user2keywords(data, keyword_list, x))
        userKey = np.array(userKey.dist.values.tolist())
        return userKey

    # get tweet-key matrix: tweet --> keywords count
    def get_tweet2keywords(self, keyword_list, tweet):
        tempKey = tweet.split()
        tempCount = dict.fromkeys(keyword_list, 0)

        for word in set(tempKey):
            tempCount[word] = tempKey.count(word)
        return list(tempCount.values())

    # construct tweet-keyword Matrix: for every tweet
    def get_tweets2keywords(self, tweet2index, keyword_list):
        tweets2keywords = pd.DataFrame(list(tweet2index.keys()), columns=['tweet'])
        tic2 = time.time()
        tweets2keywords['dist'] = tweets2keywords.tweet.parallel_apply(lambda x: self.get_tweet2keywords(keyword_list, x))
        tweets2keywords = np.array(tweets2keywords.dist.values.tolist())
        return tweets2keywords

    # interpolation function
    def phi(self, nz_index, tweet2index, index, r):
        if index in nz_index:
            return 1
        s = 0
        for i in nz_index:
            s += np.exp(- r * np.linalg.norm(np.array(tweet2index[index, :]) - np.array(tweet2index[i, :]), 2) ** 2) / 4
        if s < 0.2:
            return 0
        else:
            return s

    # son-process function
    def interpolation(self, result, bimatrix, tweets2keywords, k, num_process):
        for i in range(bimatrix.shape[0]):
            if i % num_process == k:
                print('process', k, '{} / {}'.format(i, bimatrix.shape[0]))
                nz_index = np.where(bimatrix[i, :] > 0)[0]
                index = np.arange(bimatrix.shape[1])
                result[i] = np.vectorize(self.phi, \
                                         excluded=['nz_index', 'tweetKey'])(nz_index=nz_index,
                                                                            tweet2index=tweets2keywords,
                                                                            index=index, r=2)

    # Message Similarity (M-Module): Second Step
    def Mmodule(self, bimatrix, tweets2keywords, num_process):
        """
        K assigns the number of processes
        """
        manager = Manager()
        result = manager.dict()

        plist = []
        for k in range(num_process):
            temp = Process(target=self.interpolation,
                           args=(result, bimatrix, tweets2keywords, k, num_process))
            plist.append(temp)

        for i in plist:
            i.start()
        for i in plist:
            i.join()

        new_features = []
        for _, j in sorted(dict(result).items(), key=lambda x: x[0]):
            new_features.append(j)
        new_features = np.array(new_features)

        return new_features

    # First Step Process
    def build_key_matrix(self, data):
        # get Maps
        self.user2index, self.tweet2index = self.get_user2index(data), self.get_tweet2index(data)
        # get biMatrix
        self.userTweet = self.get_bimatrix(self.user2index, self.tweet2index, data)
        # get keyList
        self.keyword_list = self.get_keywordList(data)
        # userKey
        self.users2keywords = self.get_users2keywords(self.user2index, data, self.keyword_list)
        # tweetKey
        self.tweets2keywords = self.get_tweets2keywords(self.tweet2index, self.keyword_list)
        # bimatrix
        self.bimatrix = self.get_bimatrix(self.user2index, self.tweet2index, data)

    def build_index_mapping_only(self):
        # get Maps
        self.user2index, self.tweet2index = self.get_user2index(self.data), self.get_tweet2index(self.data)
        # get keyList
        self.keyword_list = self.get_keywordList(self.data)
        # userKey
        self.users2keywords = self.get_users2keywords(self.user2index, self.data, self.keyword_list)
        # tweetKey
        self.tweets2keywords = self.get_tweets2keywords(self.tweet2index, self.keyword_list)

    def build(self):
        self.build_key_matrix(self.data)
        if self.mode == "multiply":
            # normalize by 2-norm
            users2keywords = self.users2keywords / (self.users2keywords ** 2).sum(axis=1).reshape(-1, 1) ** 0.5
            tweets2keywords = self.tweets2keywords / (self.tweets2keywords ** 2).sum(axis=1).reshape(-1, 1) ** 0.5
            return users2keywords @ tweets2keywords.T
        elif self.mode == "m_smooth":
            features = self.Mmodule(self.bimatrix, self.tweets2keywords, self.num_process)
            return features
        else:
            raise NotImplementedError(self.module_name)

# %% [markdown]
# ### Dataset

# %%
class DatasetBase():
    def __init__(self):
        self.name = "DatasetBase"

    # tokenize filter
    def lenFilter(self, word):
        return len(word) >= 2

    # tokenize
    def tokenize(self, text, stopwords=[], keyword=[]):
        # get rid of URL
        original_text = str(text).lower()
        tok = original_text.split(' ')
        text = u''
        for x in tok:
            if len(keyword) > 0:
                if x not in keyword: continue
            elif len(stopwords) > 0:
                if len(x) == 0:
                    continue
                elif x[0:4] == 'http' or x[0:5] == 'https':
                    continue
                elif x[0] == '@':
                    continue
                elif x in stopwords:
                    continue
            text = text + ' ' + x
        translate_to = u' '

        word_sep = u" ,.?:;'\"/<>`!$%^&*()-=+~[]\\|{}()\n\t" \
                   + u"©℗®℠™،、⟨⟩‒–—―…„“”–――»«›‹‘’：（）！？=【】　・" \
                   + u"⁄·† ‡°″¡¿÷№ºª‰¶′″‴§|‖¦⁂❧☞‽⸮◊※⁀「」﹁﹂『』﹃﹄《》―—" \
                   + u"“”‘’、，一。►…¿«「」ー⋘▕▕▔▏┈⋙一ー।;!؟"
        word_sep = u'#' + word_sep
        translate_table = dict((ord(char), translate_to) for char in word_sep)
        tokens = text.translate(translate_table).split(' ')
        return ' '.join(sorted(list(filter(self.lenFilter, tokens))))

    # from rawTweet to clean keyword text
    def textProcess(self, data, keyword_path, stopword_path, kthreshold, uthreshold):
        stopwords = []
        keyword = []
        if keyword_path == 'N':
            # get stopwords
            with open(stopword_path, 'r') as infile:
                for word in infile.readlines():
                    stopwords.append(word[:-1])

            data['postTweet'] = data.rawTweet.parallel_apply(
                lambda x: self.tokenize(x, stopwords=stopwords, keyword=[]))
        else:
            # get stopwords
            with open('processed/keyword.txt', 'r') as infile:
                for word in infile.readlines():
                    keyword.append(word[:-1])
            data['postTweet'] = data.rawTweet.parallel_apply(
                lambda x: self.tokenize(x, stopwords=[], keyword=keyword))

        """
        # number of keywords >= 5
        data['keyN'] = data.postTweet.apply(lambda x: len(x.split()))
        data = data[data.keyN >= kthreshold]

        userDict = dict()
        for u in data.name.values:
            try:
                userDict[u] += 1
            except:
                userDict[u] = 1

        pickedPopUsers = np.array(list(userDict.keys()))[np.where(np.array(list(userDict.values())) >= uthreshold)]
        data = data[data.name.isin(pickedPopUsers)]
        data.reset_index(drop=True, inplace=True)
        """

        return data

    def getAdjMatrix(self, nameList, user2id, csv_path, add_self_loop=True, directed=True):
        friend = pd.read_csv(csv_path, sep='\t')

        adjTable = sp.lil_matrix((len(nameList), len(nameList)))

        for u1, u2 in friend.values:
            if (u1 in nameList) and (u2 in nameList):
                adjTable[user2id[u1], user2id[u2]] += 1
                if not directed:
                    adjTable[user2id[u2], user2id[u1]] += 1
        if add_self_loop:
            adjTable += sp.diags([1.0], shape=(len(nameList), len(nameList)))
        # A = A / A.sum(axis=1).reshape(-1, 1)
        # A = (A + np.diag(np.ones(A.shape[0]))) / 2
        return adjTable

    def build(self):
        raise NotImplementedError(self.name)

    def get_feature_similarity_matrix(self):
        raise NotImplementedError(self.name)

# %%
class MFDataset(DatasetBase):
    def __init__(self, csv_path, friend_path, keyword_path, stopword_path,
                 mode="multiply", kthreshold=5, uthreshold=3, num_process=40,
                 add_self_loop=True, directed=True, args=None):
        super(MFDataset).__init__()
        self.name = "MFDataset"
        self.csv_path = csv_path
        self.kthreshold = kthreshold
        self.uthreshold = uthreshold
        self.mode = mode
        self.keyword_path = keyword_path
        self.stopword_path = stopword_path
        self.num_process = num_process
        self.friend_path = friend_path
        self.add_self_loop = add_self_loop
        self.directed = directed
        self.args = args

        self.feature_builder = None

    def build(self):
        print("{} Building...".format(self.name))
        data = pd.read_csv(self.csv_path, sep='\t')
        processed_data = self.textProcess(data, self.keyword_path, self.stopword_path, self.kthreshold, self.uthreshold)
        # Dump tweet label for eval
        self.dump_assertion_label(processed_data)
        self.feature_builder = MFFeatureBuilder(processed_data=processed_data, mode=self.mode,
                                                num_process=self.num_process)
        features = self.feature_builder.build()
        user2index = self.feature_builder.user2index
        name_list = processed_data.name.unique().tolist()
        adj_matrix = self.getAdjMatrix(name_list, user2index, self.friend_path,
                                       add_self_loop=self.add_self_loop, directed=self.directed)
        print("{} Processing Done".format(self.name))
        return adj_matrix, features, None, name_list

    def dump_assertion_label(self, processed_data):
        labels = []
        with open("dataset/eurovision/annotations_asser_label.pkl", "rb") as fin:
            tweet2label = pickle.load(fin)
        failed = 0
        for i, assertion in enumerate(processed_data.postTweet.unique()):
            asser = assertion.replace(" rt ", " ").replace(" ht ", " ").replace(" in ", " ")
            if asser not in tweet2label.keys():
                failed += 1
                labels.append(4096)
            else:
                labels.append(tweet2label[asser])
        with open(self.args.output_path + "/MF_feature_dim1_label.pkl", "wb") as fout:
            pickle.dump(np.array(labels).astype("int32"), fout)
            print("Assertion Label Dump Success.")


    def get_feature_similarity_matrix(self):
        normed_t2k = self.feature_builder.tweets2keywords / self.feature_builder.tweets2keywords.sum(axis=1).reshape(-1, 1)
        # normed_t2k = self.feature_builder.tweets2keywords
        return normed_t2k @ normed_t2k.transpose()

# %%
class TwitterDataset(MFDataset):
    def __init__(self, csv_path, keyword_path, stopword_path,
                     mode="multiply", kthreshold=5, uthreshold=3, num_process=40,
                     add_self_loop=True, directed=True, args=None):
        super(TwitterDataset, self).__init__(csv_path, None, keyword_path, stopword_path,
                                            mode, kthreshold, uthreshold, num_process, add_self_loop, directed, args)
        self.name = "TwitterDataset"
        self.processed_data = None
        self.user_label = None
        self.asser_label = None
        self.asserlist = None
        self.name_list = None

        pkl_path = "/".join(args.data_path.split("/")[:-1])
        if not os.path.exists(pkl_path + "/" + "TwitterDataset.pkl"):
            print("Preprocess and dump dataset...")
            self.preprocessing()
            """with open(pkl_path + "/" + "TwitterDataset.pkl", "wb") as fout:
                pickle.dump([self.data, self.processed_data, self.name_list, self.feature_builder], fout)"""
        else:
            print("Use existing dataset pkl {} (Remove file to re-build) ...".format(pkl_path + "/" + "TwitterDataset.pkl"))
            with open(pkl_path + "/" + "TwitterDataset.pkl", "rb") as fin:
                self.data, self.processed_data, self.name_list, self.feature_builder = pickle.load(fin)

    def preprocessing(self):
        # Preprocessing
        self.data = pd.read_csv(self.csv_path, sep='\t')
        self.processed_data = self.textProcess(self.data, self.keyword_path, self.stopword_path, self.kthreshold, self.uthreshold)
        self.name_list = self.processed_data.name.unique().tolist()

        # Feature builder for index mapping
        self.feature_builder = MFFeatureBuilder(processed_data=self.processed_data, mode=self.mode,
                                                num_process=self.num_process)
        self.feature_builder.build_index_mapping_only()

    def build(self):
        print("{} Building...".format(self.name))

        self.num_user = self.feature_builder.users2keywords.shape[0]
        print('Num users:', self.num_user)
        self.num_assertion = self.feature_builder.tweets2keywords.shape[0]
        self.num_nodes = self.num_user + self.num_assertion
        # Heterogeneous adjacent matrix
        self.het_matrix = sp.lil_matrix((self.num_nodes, self.num_nodes))

        # Get tweeting matrix
        tweeting_matrix = self.get_tweeting_matrix(self.processed_data, self.num_user, self.num_assertion)
        self.het_matrix[:self.num_user, self.num_user:self.num_user + self.num_assertion] = tweeting_matrix
        self.het_matrix[self.num_user:self.num_user + self.num_assertion, :self.num_user] = tweeting_matrix.transpose()

        # Get following matrix
        if self.args.use_follow:
            following_matrix = self.get_following_matrix()
            self.het_matrix[:self.num_user, :self.num_user] = following_matrix

        print("{} Processing Done".format(self.name))
        # Return adj matrix
        return self.het_matrix

    def cosine_similarity(self, a, b):
        return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b) + 1e-07)

    def get_following_matrix(self):
        assert self.args.use_follow
        assert self.args.follow_path is not None
        following_matrix = np.zeros([self.num_user, self.num_user])
        str_name_list = [str(k) for k in self.name_list]
        with open(self.args.follow_path, "r") as fin:
            for line in fin:
                splts = line.strip().split("	")
                if splts[0] in str_name_list and splts[1] in str_name_list:
                    fr = str_name_list.index(splts[0])
                    to = str_name_list.index(splts[1])
                else:
                    continue
                following_matrix[fr][to] = 1
                following_matrix[to][fr] = 1
        return following_matrix

    def get_tweet_similarity_matrix(self, processed_data):
        X = []
        for tweet in processed_data.postTweet.unique():
            X.append(tweet.split(" "))
        builder = TfidfEmbeddingVectorizer(X=X)
        X_emb = builder.transform(X)
        X_emb = np.array(X_emb)
        similarity_matrix = np.array(self.cosine_similarity(X_emb, dense_output=True))
        return similarity_matrix

    def get_mention_matrix(self, processed_data, num_user):
        assert self.name_list is not None
        mention_matrix = np.zeros((num_user, num_user))
        for i, item in processed_data.iterrows():
            user_name = item["name"]
            init_tweet = item["rawTweet"]
            splits = init_tweet.split(" ")
            mention_name = None
            if splits[0] == "RT":
                mention_name = splits[1].strip().replace("@", "").replace(":", "")
            if mention_name is not None and user_name in self.name_list and mention_name in self.name_list:
                mention_matrix[self.name_list.index(user_name)][self.name_list.index(mention_name)] += 1
                mention_matrix[self.name_list.index(mention_name)][self.name_list.index(user_name)] += 1
        return mention_matrix

    def get_tweeting_matrix(self, processed_data, num_user, num_assertion):
        tweeting_matrix = np.zeros((num_user, num_assertion))
        for i, item in processed_data.iterrows():
            postTweet = item["postTweet"]
            tweet_index = self.feature_builder.tweet2index[postTweet]
            user_name = item["name"]
            user_index = self.feature_builder.user2index[user_name]
            tweeting_matrix[user_index][tweet_index] += 1
        return tweeting_matrix

    def dump_label(self):
        assert self.processed_data is not None
        # Assume there is a label field in data.csv. 0 for unknown, 1 for trump, 2 for biden
        num_assertion = self.feature_builder.tweets2keywords.shape[0]

        # calculate tweet assertion label
        self.asser_label = np.zeros(num_assertion).astype("int32")
        self.asserlist = [None for _ in range(num_assertion)]
        for i, item in self.processed_data.iterrows():
            label = item["label"]
            postTweet = item["postTweet"]
            tweet_id = self.feature_builder.tweet2index[postTweet]
            if self.asserlist[tweet_id] is None:
                self.asserlist[tweet_id] = item["rawTweet"]
            if self.asser_label[tweet_id] == 0:
                self.asser_label[tweet_id] = label

        # calculate tweet label
        num_user = self.feature_builder.users2keywords.shape[0]
        self.user_label = np.zeros(num_user).astype("int32")
        user_label_candidate = [[] for _ in range(num_user)]
        for i, item in self.processed_data.iterrows():
            label = item["label"]
            user_name = item["name"]
            user_index = self.feature_builder.user2index[user_name]
            if label != 0:
                user_label_candidate[user_index].append(label)
        for i in range(num_user):
            if not user_label_candidate[i]:
                self.user_label[i] = 0
            else:
                self.user_label[i] = Counter(user_label_candidate[i]).most_common(1)[0][0]

        # dump label to label.bin
        save_path = self.args.output_path + "/label.bin"
        with open(save_path, "wb") as fout:
            pickle.dump({"user_label": self.user_label, "assertion_label": self.asser_label}, fout)

        # dump the representative assertion list
        save_path = self.args.output_path + "/asserlist.json"
        with open(save_path, "w", encoding="utf-8") as fout:
            json.dump(self.asserlist, fout, indent=2)

        # dump namelist for evaluation
        with open(self.args.output_path + "/namelist.json", 'w') as fout:
            json.dump(self.name_list, fout, indent=2)

        # dump tweet to assertion id mapping
        tweet2asserid = {}
        for i, item in self.processed_data.iterrows():
            postTweet = item["postTweet"]
            if "id" in item.keys():
                tweet_id = item["id"]
            else:
                tweet_id = item["tweet_id"]
            assertion_id = self.feature_builder.tweet2index[postTweet]
            tweet2asserid[tweet_id] = assertion_id
        with open(self.args.output_path + "/tweet_to_assertion_id_map.json", 'w') as fout:
            json.dump(tweet2asserid, fout, indent=2)

        print("Dump Label file success {}".format(save_path))

    def dump_processed_data(self):
        self.processed_data.to_csv(self.args.output_path + "/" + "processed_data.csv",
                                   sep="\t", encoding="utf-8", index=False)
        print("Dump processed data success {}".format(self.args.output_path + "/" + "processed_data.csv"))

# %% [markdown]
# ### Evaluator

# %%
class Evaluator:
    def __init__(self, user_plot_config=None, asser_plot_config=None):
        self.initialized = False
        self.output_dir = None
        self.embedding = None
        self.labels = None
        self.user_label = None
        self.asser_label = None
        self.user_clustering_pred = None
        self.asser_clustering_pred = None
        self.namelist = None
        self.asserlist = None
        self.num_user = -1
        self.num_asser = -1
        self.user_plot_config = [
            [1, "#178bff", "User Con"],
            # [0, "#3b3b3b", "User Neu"],
            [2, "#ff5c1c", "User Pro"]
        ] if user_plot_config is None else user_plot_config
        self.asser_plot_config = [
            [1, "#30a5ff", "Assertion Con"],
            # [0, "#4d4d4d", "Assertion Neu"],
            [2, "#fc8128", "Assertion Pro"]
        ] if asser_plot_config is None else asser_plot_config

    def initialize(self):
        if self.labels is not None:
            self.user_label = self.labels["user_label"]
            self.asser_label = self.labels["assertion_label"]
        self.num_user = self.user_label.shape[0]
        self.num_asser = self.asser_label.shape[0]

        for item in self.asser_plot_config:
            item[0] += 1000
        self.asser_label += 1000

        self.initialized = True

    def init_from_dir(self, dir):
        with open(dir + "/embedding.bin", 'rb') as fin:
            self.embedding = pickle.load(fin)
        with open(dir + "/label.bin", 'rb') as fin:
            self.labels = pickle.load(fin)
        with open(dir + "/namelist.json", 'r') as fin:
            self.namelist = json.load(fin)
        with open(dir + "/asserlist.json", 'r') as fin:
            self.asserlist = json.load(fin)
        self.output_dir = dir
        self.initialize()

    def init_from_value(self, embedding, user_label, asser_label, namelist, asserlist, output_dir="."):
        self.embedding = embedding
        self.user_label = user_label
        self.asser_label = asser_label
        self.namelist = namelist
        self.asserlist = asserlist
        self.output_dir = output_dir
        self.initialize()

    def run_clustering(self, n_clusters=2):
        assert n_clusters == 2

        self.user_clustering_pred, _ = self.k_means(self.embedding[:self.num_user])
        self.asser_clustering_pred, _ = self.k_means(self.embedding[self.num_user:])

        for i in range(self.num_user):
            self.user_clustering_pred[i] = \
                self.user_plot_config[0][0] if self.user_clustering_pred[i] == 0 else self.user_plot_config[1][0]

        for i in range(self.num_asser):
            self.asser_clustering_pred[i] = \
                self.asser_plot_config[0][0] if self.asser_clustering_pred[i] == 0 else self.asser_plot_config[1][0]

    def plot_clustering(self, permulate=None, show=False, save=True, tag=""):
        print("Evaluator plot clustering prediction with config:")
        print("user_plot_config: " + str(self.user_plot_config))
        print("asser_plot_config: " + str(self.asser_plot_config))
        assert self.user_clustering_pred is not None
        assert self.asser_clustering_pred is not None
        pred = np.concatenate([self.user_clustering_pred, self.asser_clustering_pred], axis=0)
        label = np.concatenate([self.user_label, self.asser_label], axis=0)
        # Only plot labeled data
        pred[label == 0] = -1
        pred[label == 1000] = -2
        if self.embedding.shape[1] == 1:
            self.plot_1d(self.embedding, pred, self.user_plot_config, self.asser_plot_config, show, save)
        elif self.embedding.shape[1] == 2:
            self.plot_2d(self.embedding, pred, self.user_plot_config, self.asser_plot_config, show, save)
        elif self.embedding.shape[1] == 3:
            self.plot_3d(self.embedding, pred, self.user_plot_config, self.asser_plot_config, permulate, show, save, tag=tag)

    def dump_topk_json(self, K=50):
        save_path = self.output_dir + "/top_tweet_table.json".format(K)
        res = {"reprA": [], "reprB": [], "reprC": []}

        collection = [(
            self.asserlist[i],
            self.embedding[self.num_user + i][0]
        ) for i in range(self.num_asser)]
        collection = sorted(collection, key=lambda x: x[1], reverse=True)
        for item in collection[:K]:
            res["reprA"].append(item[0])

        collection = [(
            self.asserlist[i],
            self.embedding[self.num_user + i][1]
        ) for i in range(self.num_asser)]
        collection = sorted(collection, key=lambda x: x[1], reverse=True)
        for item in collection[:K]:
            res["reprB"].append(item[0])

        collection = [(
            self.asserlist[i],
            self.embedding[self.num_user + i][2]
        ) for i in range(self.num_asser)]
        collection = sorted(collection, key=lambda x: x[1], reverse=True)
        for item in collection[:K]:
            res["reprC"].append(item[0])

        with open(save_path, "w") as fout:
            json.dump(res, fout, indent=2)

    def plot(self, permulate=None, show=False, save=True, tag=""):
        print("Evaluator plot label with config:")
        print("user_plot_config: " + str(self.user_plot_config))
        print("asser_plot_config: " + str(self.asser_plot_config))
        label = np.concatenate([self.user_label, self.asser_label], axis=0)
        if self.embedding.shape[1] == 1:
            self.plot_1d(self.embedding, label, self.user_plot_config, self.asser_plot_config, show, save)
        elif self.embedding.shape[1] == 2:
            self.plot_2d(self.embedding, label, self.user_plot_config, self.asser_plot_config, show, save)
        elif self.embedding.shape[1] == 3:
            self.plot_3d(self.embedding, label, self.user_plot_config, self.asser_plot_config, permulate, show, save, tag=tag)

    def purity_score(self, y_true, y_pred):
        # compute contingency matrix (also called confusion matrix)
        contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
        # return purity
        return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

    def numerical_evaluate(self, verbose=False):
        user_pred = self.user_clustering_pred[self.user_label != 0]
        user_pred_reverse = user_pred.copy()  # 1 --> 2; 2--> 1
        user_pred_reverse = 3 - user_pred_reverse
        user_label = self.user_label[self.user_label != 0]

        asser_pred = self.asser_clustering_pred[self.asser_label != 1000]
        asser_pred_reverse = asser_pred.copy()  # 1001 --> 1002; 1002 --> 1001
        asser_pred_reverse = 2003 - asser_pred_reverse
        asser_label = self.asser_label[self.asser_label != 1000]

        user_pre = [precision_score(user_label, user_pred, pos_label=1),
                    precision_score(user_label, user_pred_reverse, pos_label=1)]
        user_recall = [recall_score(user_label, user_pred, pos_label=1),
                       recall_score(user_label, user_pred_reverse, pos_label=1)]
        user_f1 = [f1_score(user_label, user_pred, pos_label=1),
                   f1_score(user_label, user_pred_reverse, pos_label=1)]

        asser_pre = [precision_score(asser_label, asser_pred, pos_label=1001),
                     precision_score(asser_label, asser_pred_reverse, pos_label=1001)]
        asser_recall = [recall_score(asser_label, asser_pred, pos_label=1001),
                        recall_score(asser_label, asser_pred_reverse, pos_label=1001)]
        asser_f1 = [f1_score(asser_label, asser_pred, pos_label=1001),
                    f1_score(asser_label, asser_pred_reverse, pos_label=1001)]

        log_content = ""
        log_content += "#User: {}, #Assertion: {}".format(self.num_user, self.num_asser) + "\n"
        log_content += "User precision: {:.4f}  User recall: {:.4f}  User F1: {:.4f}".format(user_pre[0], user_recall[0], user_f1[0]) + "\n"
        log_content += "User precision: {:.4f}  User recall: {:.4f}  User F1: {:.4f}".format(user_pre[1], user_recall[1], user_f1[1]) + "\n"
        log_content += "User Purity: {:.4f}".format(self.purity_score(user_label, user_pred)) + "\n"
        log_content += "Assertion precision: {:.4f}  Assertion recall: {:.4f}  Assertion F1: {:.4f}".format(
            asser_pre[0], asser_recall[0], asser_f1[0]) + "\n"
        log_content += "Assertion precision: {:.4f}  Assertion recall: {:.4f}  Assertion F1: {:.4f}".format(
            asser_pre[1], asser_recall[1], asser_f1[1]) + "\n"
        log_content += "Assertion Purity: {:.4f}".format(self.purity_score(asser_label, asser_pred)) + "\n"
        if verbose:
            print(log_content)

        best_arg = np.argmax(user_f1)
        if best_arg == 0:
            best = user_pred
        else:
            best = user_pred_reverse
        return log_content, max(user_f1[0], user_f1[1]), max(asser_f1[0], asser_f1[1]), best, user_label

    # -------------------------------- Function Utils --------------------------------

    def dbscan(self, embedding, cosine_norm=False, eps=0.5, min_samples=5):
        db = DBSCAN(eps=eps, min_samples=min_samples)
        if cosine_norm:
            length = np.sqrt((embedding ** 2).sum(axis=1))[:, None]
            embedding = embedding / length
        clustering = db.fit(embedding)
        pred = clustering.labels_
        pred[pred < 0] = 0
        return pred, clustering

    def mean_shift(self, embedding, cosine_norm=False, bandwidth=None):
        ms = MeanShift(bandwidth=bandwidth)
        if cosine_norm:
            length = np.sqrt((embedding ** 2).sum(axis=1))[:, None]
            embedding = embedding / length
        clustering = ms.fit(embedding)
        return clustering.labels_, clustering

    def k_means(self, embedding, cosine_norm=False, n_clusters=2, n_init=10):
        km = KMeans(
            n_clusters=n_clusters, n_init=n_init
        )

        if cosine_norm:
            length = np.sqrt((embedding ** 2).sum(axis=1))[:, None]
            embedding = embedding / length

        km_result = km.fit_predict(embedding)
        return km_result, km

    def time_tag(self):
        return time.strftime("%Y%m%d%H%M%S_", time.localtime()) + str(time.time()).split(".")[1]

    def plot_1d(self, embedding, label, user_plot_config, asser_plot_config, show=False, save=True):
        assert embedding.shape[1] == 1
        assert embedding.shape[0] == label.shape[0]

        for l, c, t in user_plot_config:
            emb = embedding[label == l]
            plt.scatter(emb[:, 0].reshape(-1),
                        np.zeros(emb[:, 0].reshape(-1).shape) + 0.15 * np.random.random(
                            size=emb[:, 0].reshape(-1).shape),
                        marker="o", color=c, label=t, s=10)

        for l, c, t in asser_plot_config:
            emb = embedding[label == l]
            plt.scatter(emb[:, 0].reshape(-1),
                        np.ones(emb[:, 0].reshape(-1).shape) + 0.15 * np.random.random(
                            size=emb[:, 0].reshape(-1).shape),
                        marker="^", color=c, label=t, s=10)

        plt.tick_params(labelsize=14)
        plt.legend(loc='best', prop={'size': 14})
        if save:
            plt.savefig(self.output_dir + "/1d_evaluation_{}.jpg".format(self.time_tag()), dpi=500)
        if show:
            plt.show()

    def plot_2d(self, embedding, label, user_plot_config, asser_plot_config, show=False, save=True):
        assert embedding.shape[1] == 2
        assert embedding.shape[0] == label.shape[0]

        for l, c, t in user_plot_config:
            emb = embedding[label == l]
            plt.scatter(emb[:, 0].reshape(-1), emb[:, 1].reshape(-1), marker="o", color=c, label=t, s=10)

        for l, c, t in asser_plot_config:
            emb = embedding[label == l]
            plt.scatter(emb[:, 0].reshape(-1), emb[:, 1].reshape(-1), marker="^", color=c, label=t, s=10)

        plt.tick_params(labelsize=16)
        plt.legend(loc='best', prop={'size': 14})
        if save:
            plt.savefig(self.output_dir + "/2d_evaluation_{}.jpg".format(self.time_tag()), dpi=500)
        if show:
            plt.show()

    def plot_3d(self, embedding, label, user_plot_config, asser_plot_config, permulate=None, show=False, save=True, tag=""):
        if permulate is None:
            permulate = [0, 1, 2]
        assert embedding.shape[1] == 3
        assert embedding.shape[0] == label.shape[0]

        fig = plt.figure(figsize=(8, 6))
        ax = fig.add_subplot(111, projection='3d')

        for l, c, t in user_plot_config:
            emb = embedding[label == l]
            ax.scatter(emb[:, permulate[0]].reshape(-1), emb[:, permulate[1]].reshape(-1), emb[:, permulate[2]].reshape(-1),
                       marker="o", color=c, label=t)

        for l, c, t in asser_plot_config:
            emb = embedding[label == l]
            ax.scatter(emb[:, permulate[0]].reshape(-1), emb[:, permulate[1]].reshape(-1), emb[:, permulate[2]].reshape(-1),
                       marker="^", color=c, label=t)

        plt.legend(loc='upper right', prop={'size': 14})
        ax.set_xlabel("Dim 1")
        ax.set_ylabel("Dim 2")
        ax.set_zlabel("Dim 3")
        ax.view_init(20, 120)

        if save:
            plt.savefig(self.output_dir + "/3d_evaluation_cluster_{}_{}.pdf".format(tag, self.time_tag()), bbox_inches='tight')
        if show:
            plt.show()

# %% [markdown]
# ### Trainer

# %%
def sp_sparse_to_torch_longtensor(coo_matrix):
    i = torch.LongTensor(np.vstack((coo_matrix.row, coo_matrix.col)))
    v = torch.LongTensor(coo_matrix.data)
    return torch.sparse.LongTensor(i, v, torch.Size(coo_matrix.shape))

# %%
def sparse_to_tuple(sparse_mx):
    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

# %%
def preprocess_graph(adj):
    adj = sp.coo_matrix(adj)
    adj_ = adj + sp.eye(adj.shape[0])
    rowsum = np.array(adj_.sum(1))
    degree_mat_inv_sqrt = sp.diags(np.power(rowsum, -0.5).flatten())
    adj_normalized = adj_.dot(degree_mat_inv_sqrt).transpose().dot(degree_mat_inv_sqrt).tocoo()
    return sparse_to_tuple(adj_normalized)

# %%
def permute_dims(z):
    assert z.dim() == 2

    B, _ = z.size()
    perm_z = []
    for z_j in z.split(1, 1):
        perm = torch.randperm(B).to(z.device)
        perm_z_j = z_j[perm]
        perm_z.append(perm_z_j)

    return torch.cat(perm_z, 1)

# %%
class TrainerBase():
    def __init__(self):
        self.name = "TrainerBase"

    def train(self):
        raise NotImplementedError(self.name)

# %%
class InfoVGAETrainer(TrainerBase):
    def __init__(self, adj_matrix, features, args, dataset):
        super(InfoVGAETrainer).__init__()
        self.name = "InfoVGAETrainer"
        self.adj_matrix = adj_matrix
        self.features = features
        self.args = args
        self.dataset = dataset

        self.model = None
        self.optimizer = None
        self.D = None
        self.optimizer_D = None

        self.result_embedding = None

    def train(self):
        print("Training using {}".format(self.name))

        # Store original adjacency matrix (without diagonal entries) for later
        adj_orig = self.adj_matrix
        adj_orig = adj_orig - sp.dia_matrix((adj_orig.diagonal()[np.newaxis, :], [0]), shape=adj_orig.shape)
        adj_orig.eliminate_zeros()

        adj_train = self.adj_matrix
        adj = adj_train

        # Some preprocessing
        adj_norm = preprocess_graph(adj)

        features = sparse_to_tuple(sp.coo_matrix(self.features))

        # Create Model
        pos_weight = self.args.pos_weight_lambda * float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()
        print("Positive sample weight: {}".format(pos_weight))

        norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

        adj_label = adj_train + sp.eye(adj_train.shape[0])
        adj_label = sparse_to_tuple(adj_label)

        adj_norm = torch.sparse.FloatTensor(torch.LongTensor(adj_norm[0].T),
                                            torch.FloatTensor(adj_norm[1]),
                                            torch.Size(adj_norm[2]))
        adj_label = torch.sparse.FloatTensor(torch.LongTensor(adj_label[0].T),
                                             torch.FloatTensor(adj_label[1]),
                                             torch.Size(adj_label[2]))
        features = torch.sparse.FloatTensor(torch.LongTensor(features[0].T),
                                            torch.FloatTensor(features[1]),
                                            torch.Size(features[2]))

        weight_mask = adj_label.to_dense().view(-1) == 1
        weight_tensor = torch.ones(weight_mask.size(0))
        weight_tensor[weight_mask] = pos_weight
        ones = torch.ones(self.adj_matrix.shape[0], dtype=torch.long)
        zeros = torch.zeros(self.adj_matrix.shape[0], dtype=torch.long)

        if self.args.use_cuda:
            adj_norm = adj_norm.cuda()
            adj_label = adj_label.cuda()
            features = features.cuda()
            weight_tensor = weight_tensor.cuda()
            ones = ones.cuda()
            zeros = zeros.cuda()

        # init model and optimizer
        self.model = InfoVGAE(self.args, adj_norm)
        if self.args.use_cuda:
            self.model = self.model.cuda()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.args.learning_rate)
        self.D = Discriminator(self.args.hidden2_dim)
        if self.args.use_cuda:
            self.D = self.D.cuda()
        self.optimizer_D = torch.optim.Adam(self.D.parameters(), lr=self.args.lr_D,
                                            betas=(self.args.beta1_D, self.args.beta2_D))

        # train model
        Kp = 0.001
        Ki = -0.001
        PID = PIDControl(Kp, Ki)
        Exp_KL = 0.005
        for epoch in range(self.args.epochs):
            t = time.time()

            # Train VAE
            z = self.model.encode(features)
            A_pred = self.model.decode(z)
            D_z = self.D(z)

            vae_recon_loss = norm * F.binary_cross_entropy(A_pred.view(-1), adj_label.to_dense().view(-1),
                                                           weight=weight_tensor)
            kl_divergence = 0.5 / A_pred.size(0) * (1 + 2 * self.model.logstd - self.model.mean ** 2 -
                                                    torch.exp(self.model.logstd) ** 2).sum(1).mean()
            vae_tc_loss = (D_z[:, :1] - D_z[:, 1:]).mean() * self.args.gamma
            weight = PID.pid(Exp_KL, kl_divergence.item())  # get the weight on KL term with PI module
            vae_loss = vae_recon_loss - weight * kl_divergence + vae_tc_loss

            self.optimizer.zero_grad()
            vae_loss.backward()
            self.optimizer.step()

            # Train Discriminator
            z = self.model.encode(features)
            D_z = self.D(z)
            z_prime = self.model.encode(features)
            z_pperm = permute_dims(z_prime).detach()
            D_z_pperm = self.D(z_pperm)
            D_tc_loss = 0.5 * (F.cross_entropy(D_z, zeros) + F.cross_entropy(D_z_pperm, ones))

            self.optimizer_D.zero_grad()
            D_tc_loss.backward()
            self.optimizer_D.step()

            if epoch % 1 == 0:
                evaluator = Evaluator()
                embedding = self.model.encode(features).detach().cpu().numpy()
                evaluator.init_from_value(embedding, self.dataset.user_label.copy(), self.dataset.asser_label.copy(),
                                          self.dataset.name_list.copy(), self.dataset.asserlist.copy(),
                                          output_dir=self.args.output_path)
                # evaluator.plot(show=False, save=True, tag=str(epoch))
                evaluator.run_clustering()
                # evaluator.plot_clustering(show=False, tag=str(epoch))
                eval_log, user_f1, asser_f1, _, _ = evaluator.numerical_evaluate()
                log = "Epoch: {}, loss_recon: {:.5f}, loss_kl: {:.5f}, loss_tc: {:.5f}, loss_VAE: {:.5f}, loss_D: {:.5f}, user_f1: {:.5f}, asser_f1: {:.5f}".format(
                        epoch,
                        vae_recon_loss.item(),
                        - weight * kl_divergence,
                        vae_tc_loss.item(),
                        vae_loss.item(),
                        D_tc_loss,
                        user_f1,
                        asser_f1)
                print(log)
                with open(self.args.output_path + "/log.txt", "a") as fout:
                    fout.write("Epoch: {}\n".format(epoch))
                    fout.write(eval_log)
                    fout.write(log + "\n\n")

        self.result_embedding = self.model.encode(features).detach().cpu().numpy()

    def save(self, path=None):
        path = self.args.output_path if path is None else path
        # Save result embedding of nodes
        with open(path + "/args.json", 'w') as fout:
            json.dump(vars(self.args), fout)
        with open(path + "/embedding.bin", 'wb') as fout:
            pickle.dump(self.result_embedding, fout)
            print("Embedding and dependencies are saved in {}".format(path))

    def get_scores(self, adj_orig, edges_pos, edges_neg, adj_rec):
        def sigmoid(x):
            return 1 / (1 + np.exp(-x))

        # Predict on test set of edges
        preds = []
        pos = []
        for e in edges_pos:
            # print(e)
            # print(adj_rec[e[0], e[1]])
            preds.append(sigmoid(adj_rec[e[0], e[1]].item()))
            pos.append(adj_orig[e[0], e[1]])

        preds_neg = []
        neg = []
        for e in edges_neg:
            preds_neg.append(sigmoid(adj_rec[e[0], e[1]].data))
            neg.append(adj_orig[e[0], e[1]])

        preds_all = np.hstack([preds, preds_neg])
        labels_all = np.hstack([np.ones(len(preds)), np.zeros(len(preds_neg))])
        roc_score = roc_auc_score(labels_all, preds_all)
        ap_score = average_precision_score(labels_all, preds_all)

        return roc_score, ap_score

    def get_acc(self, adj_rec, adj_label):
        labels_all = adj_label.to_dense().view(-1).long()
        preds_all = (adj_rec > 0.5).view(-1).long()
        accuracy = (preds_all == labels_all).sum().float() / labels_all.size(0)
        return accuracy

# %% [markdown]
# ### Run All

# %%
class arguments():
  def __init__(self, model, epochs, lr, device, n_p, seed, dataset, asl, directed, data_p, data_jp, stop_p, key_p, kthresh, uthresh, hidden1, hidden2, use_feat, n_u, n_a, lam, gamma, lrD,
                beta1, beta2, output_p, use_foll, foll_p, use_cuda):
    self.model = model
    self.epochs = epochs
    self.learning_rate = lr
    self.device = device
    self.num_process = n_p
    self.seed = seed
    self.dataset = dataset
    self.add_self_loop = asl
    self.directed = directed
    self.data_path = data_p
    self.data_json_path = data_jp
    self.stopword_path = stop_p
    self.keyword_path = key_p
    self.kthreshold = kthresh
    self.uthreshold = uthresh
    self.hidden1_dim = hidden1
    self.hidden2_dim = hidden2
    self.use_feature = use_feat
    self.num_user = n_u
    self.num_assertion = n_a
    self.pos_weight_lambda = lam
    self.gamma = gamma
    self.lr_D = lrD
    self.beta1_D = beta1
    self.beta2_D = beta2
    self.output_path = output_p
    self.use_follow = use_foll
    self.follow_path = foll_p
    self.use_cuda = use_cuda

# %%
def run_InfoVGAE(data, data_path, stopword_path, seed):
  args = arguments('InfoVGAE', 300, 0.01, 0, 40, seed, data, True, False, data_path, None, stopword_path, 'N', 5, 3, 32, 2, True, None, None, 1.0, 1e-3, 1e-3, 0.5, 0.9, './output',
          False, None, False)
  if torch.cuda.is_available() and args.device != "":
      device = "cuda:{}".format(args.device)
  else:
      device = "cpu"
  setattr(args, "device", device)
  os.makedirs(args.output_path, exist_ok=True)

  np.random.seed(args.seed)
  torch.manual_seed(args.seed)

  pandarallel.initialize()

  dataset = TwitterDataset(csv_path=args.data_path,
                          keyword_path=args.keyword_path, stopword_path=args.stopword_path,
                          mode="multiply", kthreshold=args.kthreshold,
                          uthreshold=args.uthreshold, num_process=args.num_process,
                          add_self_loop=True, directed=False, args=args)
  adj_matrix = dataset.build()
  setattr(args, "num_user", dataset.num_user)
  setattr(args, "num_assertion", dataset.num_assertion)
  # dump label and namelist for evaluation
  dataset.dump_label()

  feature = sp.diags([1.0], shape=(dataset.num_nodes, dataset.num_nodes))
  setattr(args, "input_dim", dataset.num_nodes)
  trainer = InfoVGAETrainer(adj_matrix, feature, args, dataset)
  trainer.train()
  trainer.save()

  print("Running Evaluation ...")
  evaluator = Evaluator()
  evaluator.init_from_value(trainer.result_embedding, dataset.user_label, dataset.asser_label,
                            dataset.name_list, dataset.asserlist,
                            output_dir=args.output_path)
  #evaluator.plot(show=False, save=True)
  evaluator.run_clustering()
  #evaluator.plot_clustering(show=False)
  _, _, _, preds, true = evaluator.numerical_evaluate(verbose=False)
  #evaluator.dump_topk_json()
  return preds, true, dataset.feature_builder.user2index

# %% [markdown]
# ## Run Model

# %%
# options : 'euro', 'timme', 'cd', 'conref'
dat = 'timme'
# topics for CD; options 'all', 'abortion', 'marijuana', 'gayRights', or 'obama'
top = 'all'
path = './Processed/'
# whether or not to use TIMME-All when running with TIMME; False runs TIMME-Pure
t_all = False
# English stopwords from InfoVGAE
# Italian stopwords from : https://github.com/stopwords-iso/stopwords-it

if dat in ['euro', 'timme', 'cd']:
  stopwords_path = './Datasets/Stopwords/stopwords_en.txt'
else:
  stopwords_path = './Datasets/Stopwords/stopwords_it.txt'

if dat == 'cd':
  dat = dat + top

if dat == 'timme':
  if t_all:
    dat = dat + '_all'

full_path = path + dat + '_data.csv'

# %%
seeds = [0, 7, 21, 42, 69, 118, 130, 287, 574, 1024]
res = []
truth = []

for seed in seeds:
    preds, true, mapping = run_InfoVGAE(dat, full_path, stopwords_path, seed)
    res.append(preds)
    truth.append(true)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# Preprocess and dump dataset...
# TwitterDataset Building...
# Num users: 430
# TwitterDataset Processing Done
# Dump Label file success ./output/asserlist.json
# Training using InfoVGAETrainer
# Positive sample weight: 221.99753119913186
# Epoch: 0, loss_recon: 0.74218, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.74218, loss_D: 0.69314, user_f1: 0.61483, asser_f1: 0.70949
# Epoch: 1, loss_recon: 0.74189, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.74194, loss_D: 0.69339, user_f1: 0.57955, asser_f1: 0.70733
# Epoch: 2, loss_recon: 0.73305, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.73304, loss_D: 0.69273, user_f1: 0.59273, asser_f1: 0.71264
# Epoch: 3, loss_recon: 0.74026, loss_kl: 0.00000, loss_tc: -0.00005, loss_VAE: 0.74021, loss_D: 0.69416, user_f1: 0.59528, asser_f1: 0.71141
# Epoch: 4, loss_recon: 0.72870, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.72870, loss_D: 0.69361, user_f1: 0.61710, asser_f1: 0.70618
# Epoch: 5, loss_recon: 0.72166, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.72168, loss_D: 0.69341, user_f1: 0.60457, asser_f1: 0.70245
# Epoch: 6, loss_recon: 0.71762, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.71764, loss_D: 0.69326, user_f1: 0.55738, asser_f1: 0.72681
# Epoch: 7, loss_recon: 0.70878, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.70878, loss_D: 0.69323, user_f1: 0.58596, asser_f1: 0.71917
# Epoch: 8, loss_recon: 0.70533, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.70532, loss_D: 0.69314, user_f1: 0.58131, asser_f1: 0.71814
# Epoch: 9, loss_recon: 0.69955, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.69954, loss_D: 0.69298, user_f1: 0.56328, asser_f1: 0.72580
# Epoch: 10, loss_recon: 0.69634, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.69633, loss_D: 0.69305, user_f1: 0.55401, asser_f1: 0.72317
# Epoch: 11, loss_recon: 0.69590, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.69590, loss_D: 0.69285, user_f1: 0.58000, asser_f1: 0.72952
# Epoch: 12, loss_recon: 0.69025, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.69025, loss_D: 0.69326, user_f1: 0.57243, asser_f1: 0.73942
# Epoch: 13, loss_recon: 0.68835, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.68836, loss_D: 0.69334, user_f1: 0.50896, asser_f1: 0.71958
# Epoch: 14, loss_recon: 0.68630, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.68631, loss_D: 0.69308, user_f1: 0.59442, asser_f1: 0.71476
# Epoch: 15, loss_recon: 0.68748, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.68748, loss_D: 0.69293, user_f1: 0.54452, asser_f1: 0.72727
# Epoch: 16, loss_recon: 0.68388, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.68388, loss_D: 0.69315, user_f1: 0.53584, asser_f1: 0.72537
# Epoch: 17, loss_recon: 0.68429, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.68429, loss_D: 0.69280, user_f1: 0.51220, asser_f1: 0.71978
# Epoch: 18, loss_recon: 0.67565, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.67565, loss_D: 0.69284, user_f1: 0.58553, asser_f1: 0.71413
# Epoch: 19, loss_recon: 0.67185, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.67185, loss_D: 0.69212, user_f1: 0.50519, asser_f1: 0.69494
# Epoch: 20, loss_recon: 0.66674, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.66674, loss_D: 0.69171, user_f1: 0.59935, asser_f1: 0.69005
# Epoch: 21, loss_recon: 0.66198, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.66196, loss_D: 0.69140, user_f1: 0.57851, asser_f1: 0.61004
# Epoch: 22, loss_recon: 0.66585, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.66585, loss_D: 0.69044, user_f1: 0.55034, asser_f1: 0.61420
# Epoch: 23, loss_recon: 0.67030, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.67031, loss_D: 0.68807, user_f1: 0.59935, asser_f1: 0.60927
# Epoch: 24, loss_recon: 0.67668, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.67670, loss_D: 0.68886, user_f1: 0.55219, asser_f1: 0.61905
# Epoch: 25, loss_recon: 0.66843, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.66850, loss_D: 0.69023, user_f1: 0.60163, asser_f1: 0.64461
# Epoch: 26, loss_recon: 0.66218, loss_kl: 0.00000, loss_tc: -0.00005, loss_VAE: 0.66214, loss_D: 0.68646, user_f1: 0.53242, asser_f1: 0.63415
# Epoch: 27, loss_recon: 0.64940, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.64941, loss_D: 0.68568, user_f1: 0.55219, asser_f1: 0.60224
# Epoch: 28, loss_recon: 0.65854, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.65860, loss_D: 0.68652, user_f1: 0.56905, asser_f1: 0.61709
# Epoch: 29, loss_recon: 0.64988, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.64992, loss_D: 0.68129, user_f1: 0.53741, asser_f1: 0.60281
# Epoch: 30, loss_recon: 0.64292, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.64293, loss_D: 0.68052, user_f1: 0.50953, asser_f1: 0.62001
# Epoch: 31, loss_recon: 0.63629, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.63632, loss_D: 0.68099, user_f1: 0.52055, asser_f1: 0.57835
# Epoch: 32, loss_recon: 0.63308, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.63315, loss_D: 0.67964, user_f1: 0.57616, asser_f1: 0.57818
# Epoch: 33, loss_recon: 0.62430, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.62437, loss_D: 0.67489, user_f1: 0.53061, asser_f1: 0.58472
# Epoch: 34, loss_recon: 0.61519, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.61524, loss_D: 0.67233, user_f1: 0.50519, asser_f1: 0.60855
# Epoch: 35, loss_recon: 0.61262, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.61275, loss_D: 0.66865, user_f1: 0.56000, asser_f1: 0.61008
# Epoch: 36, loss_recon: 0.60341, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.60346, loss_D: 0.66192, user_f1: 0.54545, asser_f1: 0.66390
# Epoch: 37, loss_recon: 0.59832, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.59848, loss_D: 0.66084, user_f1: 0.56000, asser_f1: 0.67161
# Epoch: 38, loss_recon: 0.59630, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59641, loss_D: 0.64941, user_f1: 0.58824, asser_f1: 0.71451
# Epoch: 39, loss_recon: 0.59450, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.59467, loss_D: 0.65075, user_f1: 0.59740, asser_f1: 0.71480
# Epoch: 40, loss_recon: 0.59152, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.59174, loss_D: 0.64921, user_f1: 0.60194, asser_f1: 0.71326
# Epoch: 41, loss_recon: 0.58309, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.58322, loss_D: 0.64345, user_f1: 0.58361, asser_f1: 0.73746
# Epoch: 42, loss_recon: 0.58093, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.58109, loss_D: 0.65144, user_f1: 0.58824, asser_f1: 0.72092
# Epoch: 43, loss_recon: 0.57898, loss_kl: 0.00000, loss_tc: 0.00033, loss_VAE: 0.57931, loss_D: 0.65648, user_f1: 0.57426, asser_f1: 0.72950
# Epoch: 44, loss_recon: 0.57728, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.57729, loss_D: 0.65641, user_f1: 0.57895, asser_f1: 0.74013
# Epoch: 45, loss_recon: 0.57558, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.57577, loss_D: 0.65063, user_f1: 0.61538, asser_f1: 0.74825
# Epoch: 46, loss_recon: 0.57602, loss_kl: 0.00000, loss_tc: 0.00023, loss_VAE: 0.57625, loss_D: 0.64823, user_f1: 0.59740, asser_f1: 0.76929
# Epoch: 47, loss_recon: 0.57456, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.57468, loss_D: 0.65033, user_f1: 0.63722, asser_f1: 0.78934
# Epoch: 48, loss_recon: 0.57469, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.57488, loss_D: 0.65139, user_f1: 0.63291, asser_f1: 0.79836
# Epoch: 49, loss_recon: 0.57485, loss_kl: 0.00000, loss_tc: 0.00021, loss_VAE: 0.57506, loss_D: 0.64778, user_f1: 0.63722, asser_f1: 0.81107
# Epoch: 50, loss_recon: 0.57786, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.57799, loss_D: 0.65205, user_f1: 0.60645, asser_f1: 0.82721
# Epoch: 51, loss_recon: 0.57755, loss_kl: 0.00000, loss_tc: 0.00021, loss_VAE: 0.57776, loss_D: 0.64934, user_f1: 0.63722, asser_f1: 0.82237
# Epoch: 52, loss_recon: 0.57577, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.57591, loss_D: 0.65180, user_f1: 0.60645, asser_f1: 0.82452
# Epoch: 53, loss_recon: 0.57511, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.57531, loss_D: 0.65339, user_f1: 0.61093, asser_f1: 0.82537
# Epoch: 54, loss_recon: 0.57470, loss_kl: 0.00000, loss_tc: 0.00027, loss_VAE: 0.57497, loss_D: 0.65811, user_f1: 0.62857, asser_f1: 0.82280
# Epoch: 55, loss_recon: 0.57551, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.57556, loss_D: 0.65580, user_f1: 0.62420, asser_f1: 0.83315
# Epoch: 56, loss_recon: 0.57512, loss_kl: 0.00000, loss_tc: 0.00033, loss_VAE: 0.57544, loss_D: 0.65578, user_f1: 0.63722, asser_f1: 0.84569
# Epoch: 57, loss_recon: 0.57602, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.57615, loss_D: 0.65663, user_f1: 0.63722, asser_f1: 0.85947
# Epoch: 58, loss_recon: 0.57751, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.57771, loss_D: 0.65463, user_f1: 0.64151, asser_f1: 0.86488
# Epoch: 59, loss_recon: 0.57854, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.57873, loss_D: 0.65583, user_f1: 0.65000, asser_f1: 0.87517
# Epoch: 60, loss_recon: 0.57877, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.57893, loss_D: 0.65234, user_f1: 0.63291, asser_f1: 0.88103
# Epoch: 61, loss_recon: 0.57830, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.57849, loss_D: 0.65525, user_f1: 0.61981, asser_f1: 0.88133
# Epoch: 62, loss_recon: 0.58008, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.58024, loss_D: 0.65395, user_f1: 0.63291, asser_f1: 0.87978
# Epoch: 63, loss_recon: 0.57850, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.57867, loss_D: 0.65553, user_f1: 0.63291, asser_f1: 0.87352
# Epoch: 64, loss_recon: 0.57933, loss_kl: 0.00000, loss_tc: 0.00024, loss_VAE: 0.57957, loss_D: 0.65773, user_f1: 0.64151, asser_f1: 0.87978
# Epoch: 65, loss_recon: 0.57949, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.57956, loss_D: 0.65949, user_f1: 0.64151, asser_f1: 0.89179
# Epoch: 66, loss_recon: 0.58036, loss_kl: 0.00000, loss_tc: 0.00034, loss_VAE: 0.58070, loss_D: 0.65982, user_f1: 0.62420, asser_f1: 0.90078
# Epoch: 67, loss_recon: 0.58109, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.58116, loss_D: 0.65689, user_f1: 0.64577, asser_f1: 0.90228
# Epoch: 68, loss_recon: 0.58172, loss_kl: 0.00000, loss_tc: 0.00026, loss_VAE: 0.58198, loss_D: 0.66088, user_f1: 0.63722, asser_f1: 0.90041
# Epoch: 69, loss_recon: 0.58241, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.58262, loss_D: 0.65783, user_f1: 0.63722, asser_f1: 0.90303
# Epoch: 70, loss_recon: 0.58256, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.58268, loss_D: 0.65814, user_f1: 0.62857, asser_f1: 0.90048
# Epoch: 71, loss_recon: 0.58199, loss_kl: 0.00000, loss_tc: 0.00021, loss_VAE: 0.58220, loss_D: 0.65918, user_f1: 0.63722, asser_f1: 0.89935
# Epoch: 72, loss_recon: 0.58189, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.58208, loss_D: 0.65836, user_f1: 0.63722, asser_f1: 0.90272
# Epoch: 73, loss_recon: 0.58260, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.58277, loss_D: 0.65810, user_f1: 0.63722, asser_f1: 0.90903
# Epoch: 74, loss_recon: 0.58287, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.58309, loss_D: 0.65925, user_f1: 0.62857, asser_f1: 0.90502
# Epoch: 75, loss_recon: 0.58379, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.58395, loss_D: 0.65928, user_f1: 0.62857, asser_f1: 0.90897
# Epoch: 76, loss_recon: 0.58419, loss_kl: 0.00000, loss_tc: 0.00025, loss_VAE: 0.58444, loss_D: 0.66211, user_f1: 0.63291, asser_f1: 0.91527
# Epoch: 77, loss_recon: 0.58425, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.58429, loss_D: 0.66356, user_f1: 0.64151, asser_f1: 0.90768
# Epoch: 78, loss_recon: 0.58424, loss_kl: 0.00000, loss_tc: 0.00032, loss_VAE: 0.58456, loss_D: 0.66582, user_f1: 0.63291, asser_f1: 0.90316
# Epoch: 79, loss_recon: 0.58416, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.58422, loss_D: 0.66339, user_f1: 0.62857, asser_f1: 0.90946
# Epoch: 80, loss_recon: 0.58438, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.58455, loss_D: 0.66240, user_f1: 0.63291, asser_f1: 0.90835
# Epoch: 81, loss_recon: 0.58481, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.58503, loss_D: 0.66168, user_f1: 0.62420, asser_f1: 0.90694
# Epoch: 82, loss_recon: 0.58485, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.58496, loss_D: 0.66268, user_f1: 0.63722, asser_f1: 0.90866
# Epoch: 83, loss_recon: 0.58571, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.58587, loss_D: 0.66311, user_f1: 0.61538, asser_f1: 0.91007
# Epoch: 84, loss_recon: 0.58602, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.58619, loss_D: 0.66364, user_f1: 0.62857, asser_f1: 0.90533
# Epoch: 85, loss_recon: 0.58610, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.58625, loss_D: 0.66309, user_f1: 0.60645, asser_f1: 0.90835
# Epoch: 86, loss_recon: 0.58570, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.58586, loss_D: 0.66329, user_f1: 0.61538, asser_f1: 0.91234
# Epoch: 87, loss_recon: 0.58632, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.58652, loss_D: 0.66333, user_f1: 0.61093, asser_f1: 0.91282
# Epoch: 88, loss_recon: 0.58666, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.58678, loss_D: 0.66564, user_f1: 0.59740, asser_f1: 0.91087
# Epoch: 89, loss_recon: 0.58674, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.58696, loss_D: 0.66646, user_f1: 0.61093, asser_f1: 0.90903
# Epoch: 90, loss_recon: 0.58745, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.58761, loss_D: 0.66589, user_f1: 0.60194, asser_f1: 0.91350
# Epoch: 91, loss_recon: 0.58791, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.58793, loss_D: 0.66800, user_f1: 0.59740, asser_f1: 0.91173
# Epoch: 92, loss_recon: 0.58800, loss_kl: 0.00000, loss_tc: 0.00029, loss_VAE: 0.58829, loss_D: 0.67006, user_f1: 0.61093, asser_f1: 0.91282
# Epoch: 93, loss_recon: 0.58805, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.58809, loss_D: 0.66740, user_f1: 0.60194, asser_f1: 0.91130
# Epoch: 94, loss_recon: 0.58781, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.58794, loss_D: 0.66613, user_f1: 0.61538, asser_f1: 0.91496
# Epoch: 95, loss_recon: 0.58838, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.58861, loss_D: 0.66560, user_f1: 0.59283, asser_f1: 0.91136
# Epoch: 96, loss_recon: 0.58862, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.58876, loss_D: 0.66524, user_f1: 0.59740, asser_f1: 0.91459
# Epoch: 97, loss_recon: 0.58866, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.58882, loss_D: 0.66770, user_f1: 0.60645, asser_f1: 0.91781
# Epoch: 98, loss_recon: 0.58943, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.58956, loss_D: 0.67010, user_f1: 0.60645, asser_f1: 0.91611
# Epoch: 99, loss_recon: 0.58916, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.58930, loss_D: 0.66662, user_f1: 0.60645, asser_f1: 0.91465
# Epoch: 100, loss_recon: 0.58932, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.58942, loss_D: 0.66751, user_f1: 0.60645, asser_f1: 0.91105
# Epoch: 101, loss_recon: 0.58959, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.58975, loss_D: 0.66698, user_f1: 0.60645, asser_f1: 0.91356
# Epoch: 102, loss_recon: 0.58993, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59001, loss_D: 0.66653, user_f1: 0.59283, asser_f1: 0.91477
# Epoch: 103, loss_recon: 0.58999, loss_kl: 0.00000, loss_tc: 0.00021, loss_VAE: 0.59020, loss_D: 0.66786, user_f1: 0.60645, asser_f1: 0.91599
# Epoch: 104, loss_recon: 0.59000, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.59005, loss_D: 0.66753, user_f1: 0.60194, asser_f1: 0.91282
# Epoch: 105, loss_recon: 0.59013, loss_kl: 0.00000, loss_tc: 0.00025, loss_VAE: 0.59037, loss_D: 0.66733, user_f1: 0.58824, asser_f1: 0.91859
# Epoch: 106, loss_recon: 0.59026, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.59033, loss_D: 0.66944, user_f1: 0.60194, asser_f1: 0.91563
# Epoch: 107, loss_recon: 0.59041, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.59061, loss_D: 0.66921, user_f1: 0.60194, asser_f1: 0.91787
# Epoch: 108, loss_recon: 0.59071, loss_kl: 0.00000, loss_tc: 0.00018, loss_VAE: 0.59089, loss_D: 0.66711, user_f1: 0.59283, asser_f1: 0.91490
# Epoch: 109, loss_recon: 0.59058, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.59071, loss_D: 0.66647, user_f1: 0.60194, asser_f1: 0.91605
# Epoch: 110, loss_recon: 0.59099, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59113, loss_D: 0.66767, user_f1: 0.60645, asser_f1: 0.91937
# Epoch: 111, loss_recon: 0.59093, loss_kl: 0.00000, loss_tc: 0.00024, loss_VAE: 0.59117, loss_D: 0.66927, user_f1: 0.58824, asser_f1: 0.91386
# Epoch: 112, loss_recon: 0.59093, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.59097, loss_D: 0.66729, user_f1: 0.60645, asser_f1: 0.91465
# Epoch: 113, loss_recon: 0.59117, loss_kl: 0.00000, loss_tc: 0.00023, loss_VAE: 0.59139, loss_D: 0.66893, user_f1: 0.59740, asser_f1: 0.91240
# Epoch: 114, loss_recon: 0.59127, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59138, loss_D: 0.66929, user_f1: 0.60194, asser_f1: 0.91622
# Epoch: 115, loss_recon: 0.59133, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.59139, loss_D: 0.66907, user_f1: 0.59740, asser_f1: 0.91756
# Epoch: 116, loss_recon: 0.59147, loss_kl: 0.00000, loss_tc: 0.00024, loss_VAE: 0.59170, loss_D: 0.66990, user_f1: 0.58824, asser_f1: 0.91865
# Epoch: 117, loss_recon: 0.59165, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.59165, loss_D: 0.67491, user_f1: 0.58824, asser_f1: 0.91647
# Epoch: 118, loss_recon: 0.59173, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59187, loss_D: 0.66712, user_f1: 0.58824, asser_f1: 0.91544
# Epoch: 119, loss_recon: 0.59174, loss_kl: 0.00000, loss_tc: 0.00026, loss_VAE: 0.59200, loss_D: 0.67261, user_f1: 0.58824, asser_f1: 0.91142
# Epoch: 120, loss_recon: 0.59163, loss_kl: 0.00000, loss_tc: 0.00009, loss_VAE: 0.59172, loss_D: 0.67381, user_f1: 0.58824, asser_f1: 0.91350
# Epoch: 121, loss_recon: 0.59203, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59211, loss_D: 0.67004, user_f1: 0.60194, asser_f1: 0.91361
# Epoch: 122, loss_recon: 0.59212, loss_kl: 0.00000, loss_tc: 0.00024, loss_VAE: 0.59236, loss_D: 0.66970, user_f1: 0.58824, asser_f1: 0.92231
# Epoch: 123, loss_recon: 0.59214, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59226, loss_D: 0.66809, user_f1: 0.59740, asser_f1: 0.91870
# Epoch: 124, loss_recon: 0.59205, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59216, loss_D: 0.66960, user_f1: 0.60194, asser_f1: 0.91906
# Epoch: 125, loss_recon: 0.59230, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.59249, loss_D: 0.66937, user_f1: 0.58824, asser_f1: 0.91288
# Epoch: 126, loss_recon: 0.59215, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59226, loss_D: 0.67238, user_f1: 0.58824, asser_f1: 0.91653
# Epoch: 127, loss_recon: 0.59242, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59254, loss_D: 0.67029, user_f1: 0.58824, asser_f1: 0.91932
# Epoch: 128, loss_recon: 0.59242, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.59257, loss_D: 0.67014, user_f1: 0.58824, asser_f1: 0.91709
# Epoch: 129, loss_recon: 0.59252, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59266, loss_D: 0.67086, user_f1: 0.59740, asser_f1: 0.90952
# Epoch: 130, loss_recon: 0.59257, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.59273, loss_D: 0.67181, user_f1: 0.60194, asser_f1: 0.91513
# Epoch: 131, loss_recon: 0.59272, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.59287, loss_D: 0.67164, user_f1: 0.59740, asser_f1: 0.91834
# Epoch: 132, loss_recon: 0.59270, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.59281, loss_D: 0.67041, user_f1: 0.59740, asser_f1: 0.91465
# Epoch: 133, loss_recon: 0.59269, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59280, loss_D: 0.66869, user_f1: 0.59740, asser_f1: 0.91569
# Epoch: 134, loss_recon: 0.59293, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.59309, loss_D: 0.67037, user_f1: 0.60194, asser_f1: 0.91839
# Epoch: 135, loss_recon: 0.59320, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.59330, loss_D: 0.67213, user_f1: 0.59740, asser_f1: 0.91246
# Epoch: 136, loss_recon: 0.59289, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59302, loss_D: 0.67059, user_f1: 0.59740, asser_f1: 0.91398
# Epoch: 137, loss_recon: 0.59303, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.59318, loss_D: 0.66994, user_f1: 0.60194, asser_f1: 0.91653
# Epoch: 138, loss_recon: 0.59314, loss_kl: 0.00000, loss_tc: 0.00009, loss_VAE: 0.59322, loss_D: 0.67319, user_f1: 0.59740, asser_f1: 0.92051
# Epoch: 139, loss_recon: 0.59315, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59323, loss_D: 0.67133, user_f1: 0.59740, asser_f1: 0.91392
# Epoch: 140, loss_recon: 0.59334, loss_kl: 0.00000, loss_tc: 0.00027, loss_VAE: 0.59362, loss_D: 0.67321, user_f1: 0.59740, asser_f1: 0.91689
# Epoch: 141, loss_recon: 0.59323, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.59327, loss_D: 0.67350, user_f1: 0.59740, asser_f1: 0.91725
# Epoch: 142, loss_recon: 0.59340, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.59353, loss_D: 0.67062, user_f1: 0.59740, asser_f1: 0.91876
# Epoch: 143, loss_recon: 0.59355, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.59372, loss_D: 0.67214, user_f1: 0.59740, asser_f1: 0.91622
# Epoch: 144, loss_recon: 0.59371, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.59377, loss_D: 0.67085, user_f1: 0.59740, asser_f1: 0.92092
# Epoch: 145, loss_recon: 0.59357, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.59370, loss_D: 0.67175, user_f1: 0.59740, asser_f1: 0.91477
# Epoch: 146, loss_recon: 0.59361, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59373, loss_D: 0.67086, user_f1: 0.59740, asser_f1: 0.91834
# Epoch: 147, loss_recon: 0.59391, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59402, loss_D: 0.67176, user_f1: 0.60194, asser_f1: 0.91948
# Epoch: 148, loss_recon: 0.59397, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.59411, loss_D: 0.67129, user_f1: 0.60194, asser_f1: 0.91471
# Epoch: 149, loss_recon: 0.59396, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59404, loss_D: 0.67044, user_f1: 0.60194, asser_f1: 0.91611
# Epoch: 150, loss_recon: 0.59394, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.59409, loss_D: 0.66986, user_f1: 0.60194, asser_f1: 0.91544
# Epoch: 151, loss_recon: 0.59415, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59427, loss_D: 0.67081, user_f1: 0.60645, asser_f1: 0.91762
# Epoch: 152, loss_recon: 0.59407, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.59429, loss_D: 0.67329, user_f1: 0.60194, asser_f1: 0.92338
# Epoch: 153, loss_recon: 0.59431, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59439, loss_D: 0.67315, user_f1: 0.60194, asser_f1: 0.92045
# Epoch: 154, loss_recon: 0.59425, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.59443, loss_D: 0.67080, user_f1: 0.60194, asser_f1: 0.91906
# Epoch: 155, loss_recon: 0.59432, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59444, loss_D: 0.67255, user_f1: 0.60194, asser_f1: 0.91979
# Epoch: 156, loss_recon: 0.59438, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59452, loss_D: 0.67095, user_f1: 0.60194, asser_f1: 0.91942
# Epoch: 157, loss_recon: 0.59430, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59438, loss_D: 0.67758, user_f1: 0.60194, asser_f1: 0.91689
# Epoch: 158, loss_recon: 0.59450, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.59472, loss_D: 0.67970, user_f1: 0.60194, asser_f1: 0.92015
# Epoch: 159, loss_recon: 0.59470, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59473, loss_D: 0.67721, user_f1: 0.60194, asser_f1: 0.91792
# Epoch: 160, loss_recon: 0.59461, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59463, loss_D: 0.67761, user_f1: 0.60194, asser_f1: 0.91792
# Epoch: 161, loss_recon: 0.59475, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.59491, loss_D: 0.67128, user_f1: 0.60194, asser_f1: 0.91580
# Epoch: 162, loss_recon: 0.59473, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.59493, loss_D: 0.67336, user_f1: 0.60194, asser_f1: 0.91834
# Epoch: 163, loss_recon: 0.59496, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59510, loss_D: 0.67131, user_f1: 0.60194, asser_f1: 0.91725
# Epoch: 164, loss_recon: 0.59493, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59503, loss_D: 0.67278, user_f1: 0.60194, asser_f1: 0.91973
# Epoch: 165, loss_recon: 0.59495, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59509, loss_D: 0.67356, user_f1: 0.60194, asser_f1: 0.92087
# Epoch: 166, loss_recon: 0.59501, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59515, loss_D: 0.67436, user_f1: 0.60194, asser_f1: 0.92051
# Epoch: 167, loss_recon: 0.59498, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59510, loss_D: 0.67182, user_f1: 0.60194, asser_f1: 0.92195
# Epoch: 168, loss_recon: 0.59508, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59516, loss_D: 0.67356, user_f1: 0.60194, asser_f1: 0.92231
# Epoch: 169, loss_recon: 0.59534, loss_kl: 0.00000, loss_tc: 0.00021, loss_VAE: 0.59555, loss_D: 0.67710, user_f1: 0.60194, asser_f1: 0.91901
# Epoch: 170, loss_recon: 0.59528, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59528, loss_D: 0.67474, user_f1: 0.60194, asser_f1: 0.91683
# Epoch: 171, loss_recon: 0.59531, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.59546, loss_D: 0.67310, user_f1: 0.60194, asser_f1: 0.91683
# Epoch: 172, loss_recon: 0.59542, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59557, loss_D: 0.67409, user_f1: 0.60194, asser_f1: 0.92087
# Epoch: 173, loss_recon: 0.59552, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.59559, loss_D: 0.67440, user_f1: 0.60194, asser_f1: 0.91798
# Epoch: 174, loss_recon: 0.59542, loss_kl: 0.00000, loss_tc: 0.00009, loss_VAE: 0.59551, loss_D: 0.67385, user_f1: 0.60194, asser_f1: 0.92123
# Epoch: 175, loss_recon: 0.59557, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59569, loss_D: 0.67513, user_f1: 0.60194, asser_f1: 0.92333
# Epoch: 176, loss_recon: 0.59562, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.59569, loss_D: 0.67379, user_f1: 0.60194, asser_f1: 0.92087
# Epoch: 177, loss_recon: 0.59578, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59592, loss_D: 0.67502, user_f1: 0.60194, asser_f1: 0.92159
# Epoch: 178, loss_recon: 0.59578, loss_kl: 0.00000, loss_tc: 0.00009, loss_VAE: 0.59586, loss_D: 0.67546, user_f1: 0.60194, asser_f1: 0.92482
# Epoch: 179, loss_recon: 0.59590, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59601, loss_D: 0.67553, user_f1: 0.60194, asser_f1: 0.92123
# Epoch: 180, loss_recon: 0.59573, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.59586, loss_D: 0.67387, user_f1: 0.60194, asser_f1: 0.92231
# Epoch: 181, loss_recon: 0.59586, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59597, loss_D: 0.67413, user_f1: 0.60194, asser_f1: 0.92164
# Epoch: 182, loss_recon: 0.59588, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59596, loss_D: 0.67298, user_f1: 0.60194, asser_f1: 0.92123
# Epoch: 183, loss_recon: 0.59587, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.59602, loss_D: 0.67637, user_f1: 0.60194, asser_f1: 0.92308
# Epoch: 184, loss_recon: 0.59604, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59607, loss_D: 0.67691, user_f1: 0.60194, asser_f1: 0.92517
# Epoch: 185, loss_recon: 0.59599, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.59618, loss_D: 0.67664, user_f1: 0.60194, asser_f1: 0.92308
# Epoch: 186, loss_recon: 0.59605, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.59605, loss_D: 0.68242, user_f1: 0.60194, asser_f1: 0.92015
# Epoch: 187, loss_recon: 0.59608, loss_kl: 0.00000, loss_tc: 0.00009, loss_VAE: 0.59617, loss_D: 0.67646, user_f1: 0.60194, asser_f1: 0.92159
# Epoch: 188, loss_recon: 0.59607, loss_kl: 0.00000, loss_tc: 0.00024, loss_VAE: 0.59631, loss_D: 0.67930, user_f1: 0.60194, asser_f1: 0.91834
# Epoch: 189, loss_recon: 0.59606, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59609, loss_D: 0.68078, user_f1: 0.60194, asser_f1: 0.92231
# Epoch: 190, loss_recon: 0.59597, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.59604, loss_D: 0.67736, user_f1: 0.60194, asser_f1: 0.92441
# Epoch: 191, loss_recon: 0.59603, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.59619, loss_D: 0.67877, user_f1: 0.60194, asser_f1: 0.92164
# Epoch: 192, loss_recon: 0.59600, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.59606, loss_D: 0.68076, user_f1: 0.60194, asser_f1: 0.92267
# Epoch: 193, loss_recon: 0.59612, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.59618, loss_D: 0.67851, user_f1: 0.60194, asser_f1: 0.92374
# Epoch: 194, loss_recon: 0.59610, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.59623, loss_D: 0.67994, user_f1: 0.60194, asser_f1: 0.91870
# Epoch: 195, loss_recon: 0.59611, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.59616, loss_D: 0.68136, user_f1: 0.60194, asser_f1: 0.92344
# Epoch: 196, loss_recon: 0.59610, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.59616, loss_D: 0.68145, user_f1: 0.60194, asser_f1: 0.92231
# Epoch: 197, loss_recon: 0.59610, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.59621, loss_D: 0.68179, user_f1: 0.60194, asser_f1: 0.92482
# Epoch: 198, loss_recon: 0.59605, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59607, loss_D: 0.68789, user_f1: 0.60194, asser_f1: 0.92410
# Epoch: 199, loss_recon: 0.59611, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.59617, loss_D: 0.68470, user_f1: 0.60194, asser_f1: 0.92200
# Epoch: 200, loss_recon: 0.59612, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59624, loss_D: 0.68244, user_f1: 0.60194, asser_f1: 0.92231
# Epoch: 201, loss_recon: 0.59619, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.59623, loss_D: 0.68456, user_f1: 0.60194, asser_f1: 0.92267
# Epoch: 202, loss_recon: 0.59617, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.59622, loss_D: 0.68458, user_f1: 0.60194, asser_f1: 0.92015
# Epoch: 203, loss_recon: 0.59626, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59634, loss_D: 0.68412, user_f1: 0.60194, asser_f1: 0.92517
# Epoch: 204, loss_recon: 0.59624, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.59627, loss_D: 0.68418, user_f1: 0.60194, asser_f1: 0.92553
# Epoch: 205, loss_recon: 0.59623, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.59628, loss_D: 0.68567, user_f1: 0.60194, asser_f1: 0.92338
# Epoch: 206, loss_recon: 0.59622, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.59627, loss_D: 0.68733, user_f1: 0.60194, asser_f1: 0.92231
# Epoch: 207, loss_recon: 0.59618, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59622, loss_D: 0.68829, user_f1: 0.60194, asser_f1: 0.92338
# Epoch: 208, loss_recon: 0.59634, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.59641, loss_D: 0.69611, user_f1: 0.60194, asser_f1: 0.92045
# Epoch: 209, loss_recon: 0.59629, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59629, loss_D: 0.70129, user_f1: 0.60194, asser_f1: 0.92374
# Epoch: 210, loss_recon: 0.59625, loss_kl: 0.00000, loss_tc: -0.00004, loss_VAE: 0.59620, loss_D: 0.68934, user_f1: 0.60194, asser_f1: 0.92517
# Epoch: 211, loss_recon: 0.59623, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.59634, loss_D: 0.69443, user_f1: 0.60194, asser_f1: 0.92446
# Epoch: 212, loss_recon: 0.59642, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59643, loss_D: 0.69050, user_f1: 0.60194, asser_f1: 0.92410
# Epoch: 213, loss_recon: 0.59637, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59634, loss_D: 0.68990, user_f1: 0.60194, asser_f1: 0.92015
# Epoch: 214, loss_recon: 0.59633, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.59639, loss_D: 0.69070, user_f1: 0.60194, asser_f1: 0.92338
# Epoch: 215, loss_recon: 0.59642, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59643, loss_D: 0.69084, user_f1: 0.60194, asser_f1: 0.92051
# Epoch: 216, loss_recon: 0.59641, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59640, loss_D: 0.69077, user_f1: 0.60194, asser_f1: 0.92164
# Epoch: 217, loss_recon: 0.59638, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.59643, loss_D: 0.69086, user_f1: 0.60194, asser_f1: 0.92195
# Epoch: 218, loss_recon: 0.59644, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59642, loss_D: 0.69198, user_f1: 0.60194, asser_f1: 0.92159
# Epoch: 219, loss_recon: 0.59644, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59646, loss_D: 0.69155, user_f1: 0.60194, asser_f1: 0.92589
# Epoch: 220, loss_recon: 0.59646, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59647, loss_D: 0.69201, user_f1: 0.60194, asser_f1: 0.92267
# Epoch: 221, loss_recon: 0.59655, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59655, loss_D: 0.69246, user_f1: 0.60194, asser_f1: 0.92338
# Epoch: 222, loss_recon: 0.59659, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59661, loss_D: 0.69285, user_f1: 0.60194, asser_f1: 0.92159
# Epoch: 223, loss_recon: 0.59666, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59665, loss_D: 0.69397, user_f1: 0.60194, asser_f1: 0.92190
# Epoch: 224, loss_recon: 0.59668, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59670, loss_D: 0.69644, user_f1: 0.60645, asser_f1: 0.92482
# Epoch: 225, loss_recon: 0.59664, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59663, loss_D: 0.69521, user_f1: 0.60645, asser_f1: 0.92338
# Epoch: 226, loss_recon: 0.59657, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59656, loss_D: 0.69416, user_f1: 0.60645, asser_f1: 0.92303
# Epoch: 227, loss_recon: 0.59670, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59672, loss_D: 0.69288, user_f1: 0.60645, asser_f1: 0.92446
# Epoch: 228, loss_recon: 0.59667, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59665, loss_D: 0.69290, user_f1: 0.60645, asser_f1: 0.92482
# Epoch: 229, loss_recon: 0.59663, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59664, loss_D: 0.69356, user_f1: 0.60645, asser_f1: 0.92267
# Epoch: 230, loss_recon: 0.59674, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.59675, loss_D: 0.69339, user_f1: 0.60645, asser_f1: 0.92446
# Epoch: 231, loss_recon: 0.59667, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59666, loss_D: 0.69346, user_f1: 0.60645, asser_f1: 0.92231
# Epoch: 232, loss_recon: 0.59661, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59662, loss_D: 0.69373, user_f1: 0.60645, asser_f1: 0.92272
# Epoch: 233, loss_recon: 0.59673, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59671, loss_D: 0.69505, user_f1: 0.60645, asser_f1: 0.92267
# Epoch: 234, loss_recon: 0.59669, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59672, loss_D: 0.69578, user_f1: 0.60645, asser_f1: 0.91948
# Epoch: 235, loss_recon: 0.59667, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59665, loss_D: 0.69475, user_f1: 0.60645, asser_f1: 0.92338
# Epoch: 236, loss_recon: 0.59667, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59667, loss_D: 0.69354, user_f1: 0.60645, asser_f1: 0.92195
# Epoch: 237, loss_recon: 0.59675, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59676, loss_D: 0.69306, user_f1: 0.60645, asser_f1: 0.92584
# Epoch: 238, loss_recon: 0.59670, loss_kl: 0.00000, loss_tc: -0.00003, loss_VAE: 0.59668, loss_D: 0.69316, user_f1: 0.60645, asser_f1: 0.92451
# Epoch: 239, loss_recon: 0.59673, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.59678, loss_D: 0.69379, user_f1: 0.60645, asser_f1: 0.92200
# Epoch: 240, loss_recon: 0.59679, loss_kl: 0.00000, loss_tc: -0.00008, loss_VAE: 0.59671, loss_D: 0.69405, user_f1: 0.60645, asser_f1: 0.92420
# Epoch: 241, loss_recon: 0.59674, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.59682, loss_D: 0.69384, user_f1: 0.60645, asser_f1: 0.92272
# Epoch: 242, loss_recon: 0.59680, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59677, loss_D: 0.69346, user_f1: 0.60645, asser_f1: 0.92415
# Epoch: 243, loss_recon: 0.59682, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59680, loss_D: 0.69389, user_f1: 0.60645, asser_f1: 0.92308
# Epoch: 244, loss_recon: 0.59682, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59681, loss_D: 0.69547, user_f1: 0.60645, asser_f1: 0.92128
# Epoch: 245, loss_recon: 0.59678, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.59681, loss_D: 0.69597, user_f1: 0.60645, asser_f1: 0.92487
# Epoch: 246, loss_recon: 0.59686, loss_kl: 0.00000, loss_tc: -0.00003, loss_VAE: 0.59683, loss_D: 0.69464, user_f1: 0.60645, asser_f1: 0.92374
# Epoch: 247, loss_recon: 0.59684, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59686, loss_D: 0.69339, user_f1: 0.60645, asser_f1: 0.92379
# Epoch: 248, loss_recon: 0.59684, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.59684, loss_D: 0.69301, user_f1: 0.61538, asser_f1: 0.92159
# Epoch: 249, loss_recon: 0.59683, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59683, loss_D: 0.69329, user_f1: 0.60645, asser_f1: 0.92231
# Epoch: 250, loss_recon: 0.59692, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59693, loss_D: 0.69316, user_f1: 0.60645, asser_f1: 0.92333
# Epoch: 251, loss_recon: 0.59688, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59686, loss_D: 0.69349, user_f1: 0.60645, asser_f1: 0.92123
# Epoch: 252, loss_recon: 0.59686, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59687, loss_D: 0.69351, user_f1: 0.61538, asser_f1: 0.92410
# Epoch: 253, loss_recon: 0.59691, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59690, loss_D: 0.69389, user_f1: 0.60645, asser_f1: 0.92333
# Epoch: 254, loss_recon: 0.59687, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59687, loss_D: 0.69432, user_f1: 0.61538, asser_f1: 0.92441
# Epoch: 255, loss_recon: 0.59695, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59695, loss_D: 0.69463, user_f1: 0.61538, asser_f1: 0.92231
# Epoch: 256, loss_recon: 0.59696, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59695, loss_D: 0.69444, user_f1: 0.61538, asser_f1: 0.92195
# Epoch: 257, loss_recon: 0.59696, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59698, loss_D: 0.69403, user_f1: 0.61538, asser_f1: 0.92159
# Epoch: 258, loss_recon: 0.59696, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59694, loss_D: 0.69352, user_f1: 0.61538, asser_f1: 0.92374
# Epoch: 259, loss_recon: 0.59689, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59691, loss_D: 0.69302, user_f1: 0.61538, asser_f1: 0.92231
# Epoch: 260, loss_recon: 0.59696, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59696, loss_D: 0.69315, user_f1: 0.61093, asser_f1: 0.92553
# Epoch: 261, loss_recon: 0.59704, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59704, loss_D: 0.69309, user_f1: 0.61093, asser_f1: 0.92553
# Epoch: 262, loss_recon: 0.59695, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59696, loss_D: 0.69319, user_f1: 0.61538, asser_f1: 0.92517
# Epoch: 263, loss_recon: 0.59701, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59700, loss_D: 0.69313, user_f1: 0.61538, asser_f1: 0.92303
# Epoch: 264, loss_recon: 0.59699, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59700, loss_D: 0.69328, user_f1: 0.61538, asser_f1: 0.92123
# Epoch: 265, loss_recon: 0.59704, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59703, loss_D: 0.69375, user_f1: 0.61538, asser_f1: 0.92553
# Epoch: 266, loss_recon: 0.59701, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59701, loss_D: 0.69565, user_f1: 0.61538, asser_f1: 0.92231
# Epoch: 267, loss_recon: 0.59704, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59705, loss_D: 0.69802, user_f1: 0.61538, asser_f1: 0.92344
# Epoch: 268, loss_recon: 0.59702, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59701, loss_D: 0.69492, user_f1: 0.61538, asser_f1: 0.92272
# Epoch: 269, loss_recon: 0.59711, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59711, loss_D: 0.69298, user_f1: 0.61538, asser_f1: 0.92267
# Epoch: 270, loss_recon: 0.59713, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.59713, loss_D: 0.69328, user_f1: 0.61538, asser_f1: 0.92415
# Epoch: 271, loss_recon: 0.59705, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59705, loss_D: 0.69348, user_f1: 0.61538, asser_f1: 0.92303
# Epoch: 272, loss_recon: 0.59717, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.59717, loss_D: 0.69326, user_f1: 0.61538, asser_f1: 0.92338
# Epoch: 273, loss_recon: 0.59713, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59713, loss_D: 0.69297, user_f1: 0.61538, asser_f1: 0.92803
# Epoch: 274, loss_recon: 0.59710, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59709, loss_D: 0.69311, user_f1: 0.61538, asser_f1: 0.92410
# Epoch: 275, loss_recon: 0.59713, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.59717, loss_D: 0.69322, user_f1: 0.61538, asser_f1: 0.92477
# Epoch: 276, loss_recon: 0.59707, loss_kl: 0.00000, loss_tc: -0.00006, loss_VAE: 0.59701, loss_D: 0.69355, user_f1: 0.61538, asser_f1: 0.92446
# Epoch: 277, loss_recon: 0.59718, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.59724, loss_D: 0.69361, user_f1: 0.61538, asser_f1: 0.92482
# Epoch: 278, loss_recon: 0.59714, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59712, loss_D: 0.69337, user_f1: 0.61538, asser_f1: 0.92349
# Epoch: 279, loss_recon: 0.59721, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59720, loss_D: 0.69412, user_f1: 0.61538, asser_f1: 0.92241
# Epoch: 280, loss_recon: 0.59716, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59715, loss_D: 0.69548, user_f1: 0.61538, asser_f1: 0.92349
# Epoch: 281, loss_recon: 0.59715, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.59718, loss_D: 0.69564, user_f1: 0.61538, asser_f1: 0.92200
# Epoch: 282, loss_recon: 0.59718, loss_kl: 0.00000, loss_tc: -0.00003, loss_VAE: 0.59715, loss_D: 0.69390, user_f1: 0.61538, asser_f1: 0.92092
# Epoch: 283, loss_recon: 0.59714, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59715, loss_D: 0.69309, user_f1: 0.61538, asser_f1: 0.92308
# Epoch: 284, loss_recon: 0.59720, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59721, loss_D: 0.69311, user_f1: 0.61538, asser_f1: 0.92051
# Epoch: 285, loss_recon: 0.59721, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59720, loss_D: 0.69329, user_f1: 0.61538, asser_f1: 0.92446
# Epoch: 286, loss_recon: 0.59723, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59724, loss_D: 0.69311, user_f1: 0.61538, asser_f1: 0.92267
# Epoch: 287, loss_recon: 0.59720, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59719, loss_D: 0.69319, user_f1: 0.61538, asser_f1: 0.92267
# Epoch: 288, loss_recon: 0.59724, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59725, loss_D: 0.69316, user_f1: 0.61538, asser_f1: 0.92410
# Epoch: 289, loss_recon: 0.59724, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59723, loss_D: 0.69312, user_f1: 0.61538, asser_f1: 0.92415
# Epoch: 290, loss_recon: 0.59724, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59725, loss_D: 0.69325, user_f1: 0.61538, asser_f1: 0.92767
# Epoch: 291, loss_recon: 0.59728, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59727, loss_D: 0.69326, user_f1: 0.61538, asser_f1: 0.92415
# Epoch: 292, loss_recon: 0.59732, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.59734, loss_D: 0.69379, user_f1: 0.61538, asser_f1: 0.92563
# Epoch: 293, loss_recon: 0.59724, loss_kl: 0.00000, loss_tc: -0.00003, loss_VAE: 0.59721, loss_D: 0.69449, user_f1: 0.61538, asser_f1: 0.92701
# Epoch: 294, loss_recon: 0.59731, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.59735, loss_D: 0.69536, user_f1: 0.61538, asser_f1: 0.92456
# Epoch: 295, loss_recon: 0.59733, loss_kl: 0.00000, loss_tc: -0.00003, loss_VAE: 0.59730, loss_D: 0.69427, user_f1: 0.61538, asser_f1: 0.92384
# Epoch: 296, loss_recon: 0.59733, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.59735, loss_D: 0.69319, user_f1: 0.61538, asser_f1: 0.92308
# Epoch: 297, loss_recon: 0.59727, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.59727, loss_D: 0.69316, user_f1: 0.61981, asser_f1: 0.92451
# Epoch: 298, loss_recon: 0.59734, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.59735, loss_D: 0.69314, user_f1: 0.61538, asser_f1: 0.92374
# Epoch: 299, loss_recon: 0.59737, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.59735, loss_D: 0.69325, user_f1: 0.61538, asser_f1: 0.92625
# Embedding and dependencies are saved in ./output
# Running Evaluation ...
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# Preprocess and dump dataset...
# TwitterDataset Building...
# Num users: 430
# TwitterDataset Processing Done
# Dump Label file success ./output/asserlist.json
# Training using InfoVGAETrainer
# Positive sample weight: 221.99753119913186
# Epoch: 0, loss_recon: 0.75607, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.75607, loss_D: 0.69317, user_f1: 0.59150, asser_f1: 0.71699
# Epoch: 1, loss_recon: 0.74363, loss_kl: 0.00000, loss_tc: -0.00011, loss_VAE: 0.74352, loss_D: 0.69629, user_f1: 0.58845, asser_f1: 0.71531
# Epoch: 2, loss_recon: 0.74056, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.74054, loss_D: 0.69313, user_f1: 0.56322, asser_f1: 0.72966
# Epoch: 3, loss_recon: 0.73229, loss_kl: 0.00000, loss_tc: 0.00001, loss_VAE: 0.73230, loss_D: 0.69319, user_f1: 0.61069, asser_f1: 0.71968
# Epoch: 4, loss_recon: 0.73050, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.73052, loss_D: 0.69318, user_f1: 0.58867, asser_f1: 0.70836
# Epoch: 5, loss_recon: 0.72082, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.72084, loss_D: 0.69319, user_f1: 0.58509, asser_f1: 0.70744
# Epoch: 6, loss_recon: 0.71714, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.71716, loss_D: 0.69336, user_f1: 0.58473, asser_f1: 0.71199
# Epoch: 7, loss_recon: 0.71511, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.71512, loss_D: 0.69320, user_f1: 0.55431, asser_f1: 0.71015
# Epoch: 8, loss_recon: 0.70631, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.70630, loss_D: 0.69318, user_f1: 0.56987, asser_f1: 0.71710
# Epoch: 9, loss_recon: 0.70453, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.70451, loss_D: 0.69315, user_f1: 0.54545, asser_f1: 0.71510
# Epoch: 10, loss_recon: 0.70011, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.70010, loss_D: 0.69327, user_f1: 0.57770, asser_f1: 0.71304
# Epoch: 11, loss_recon: 0.69410, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.69409, loss_D: 0.69315, user_f1: 0.52389, asser_f1: 0.72040
# Epoch: 12, loss_recon: 0.69505, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.69505, loss_D: 0.69310, user_f1: 0.52708, asser_f1: 0.72140
# Epoch: 13, loss_recon: 0.68857, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.68857, loss_D: 0.69313, user_f1: 0.53901, asser_f1: 0.71207
# Epoch: 14, loss_recon: 0.68415, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.68415, loss_D: 0.69322, user_f1: 0.50714, asser_f1: 0.71346
# Epoch: 15, loss_recon: 0.68340, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.68341, loss_D: 0.69294, user_f1: 0.50526, asser_f1: 0.70757
# Epoch: 16, loss_recon: 0.68221, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.68222, loss_D: 0.69292, user_f1: 0.51748, asser_f1: 0.68757
# Epoch: 17, loss_recon: 0.67703, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.67703, loss_D: 0.69311, user_f1: 0.52318, asser_f1: 0.66138
# Epoch: 18, loss_recon: 0.66912, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.66912, loss_D: 0.69269, user_f1: 0.54082, asser_f1: 0.65191
# Epoch: 19, loss_recon: 0.66315, loss_kl: 0.00000, loss_tc: -0.00000, loss_VAE: 0.66315, loss_D: 0.69235, user_f1: 0.51034, asser_f1: 0.63288
# Epoch: 20, loss_recon: 0.65203, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.65203, loss_D: 0.69177, user_f1: 0.52174, asser_f1: 0.61281
# Epoch: 21, loss_recon: 0.64449, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.64449, loss_D: 0.69064, user_f1: 0.55034, asser_f1: 0.57811
# Epoch: 22, loss_recon: 0.63674, loss_kl: 0.00000, loss_tc: 0.00000, loss_VAE: 0.63674, loss_D: 0.68871, user_f1: 0.56766, asser_f1: 0.58742
# Epoch: 23, loss_recon: 0.63126, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.63123, loss_D: 0.68561, user_f1: 0.54054, asser_f1: 0.60892
# Epoch: 24, loss_recon: 0.62528, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.62533, loss_D: 0.68222, user_f1: 0.54054, asser_f1: 0.66309
# Epoch: 25, loss_recon: 0.62149, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.62152, loss_D: 0.67550, user_f1: 0.57426, asser_f1: 0.68346
# Epoch: 26, loss_recon: 0.61901, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.61908, loss_D: 0.66640, user_f1: 0.61538, asser_f1: 0.70823
# Epoch: 27, loss_recon: 0.60803, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.60809, loss_D: 0.66380, user_f1: 0.62857, asser_f1: 0.70772
# Epoch: 28, loss_recon: 0.60515, loss_kl: 0.00000, loss_tc: 0.00023, loss_VAE: 0.60539, loss_D: 0.65804, user_f1: 0.55518, asser_f1: 0.73142
# Epoch: 29, loss_recon: 0.59459, loss_kl: 0.00000, loss_tc: -0.00010, loss_VAE: 0.59450, loss_D: 0.66101, user_f1: 0.56954, asser_f1: 0.72699
# Epoch: 30, loss_recon: 0.59167, loss_kl: 0.00000, loss_tc: 0.00023, loss_VAE: 0.59190, loss_D: 0.65784, user_f1: 0.61538, asser_f1: 0.70857
# Epoch: 31, loss_recon: 0.58680, loss_kl: 0.00000, loss_tc: 0.00027, loss_VAE: 0.58707, loss_D: 0.65425, user_f1: 0.64577, asser_f1: 0.70342
# ...
# Epoch: 188, loss_recon: 0.59142, loss_kl: 0.00000, loss_tc: 0.00038, loss_VAE: 0.59180, loss_D: 0.58393, user_f1: 0.60194, asser_f1: 0.92087
# Epoch: 189, loss_recon: 0.59131, loss_kl: 0.00000, loss_tc: 0.00039, loss_VAE: 0.59170, loss_D: 0.59667, user_f1: 0.60194, asser_f1: 0.92092
# Epoch: 190, loss_recon: 0.59143, loss_kl: 0.00000, loss_tc: 0.00052, loss_VAE: 0.59194, loss_D: 0.60465, user_f1: 0.60194, asser_f1: 0.91507
# Epoch: 191, loss_recon: 0.59138, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.59160, loss_D: 0.60497, user_f1: 0.60194, asser_f1: 0.91689
# Epoch: 192, loss_recon: 0.59119, loss_kl: 0.00000, loss_tc: 0.00047, loss_VAE: 0.59166, loss_D: 0.59789, user_f1: 0.60194, asser_f1: 0.92087
# Epoch: 193, loss_recon: 0.59104, loss_kl: 0.00000, loss_tc: 0.00039, loss_VAE: 0.59144, loss_D: 0.60705, user_f1: 0.60194, asser_f1: 0.92482
# Epoch: 194, loss_recon: 0.59111, loss_kl: 0.00000, loss_tc: 0.00025, loss_VAE: 0.59136, loss_D: 0.60322, user_f1: 0.60194, asser_f1: 0.92231
# Epoch: 195, loss_recon: 0.59077, loss_kl: 0.00000, loss_tc: 0.00044, loss_VAE: 0.59121, loss_D: 0.61035, user_f1: 0.60194, asser_f1: 0.92015
# Epoch: 196, loss_recon: 0.59058, loss_kl: 0.00000, loss_tc: -0.00001, loss_VAE: 0.59057, loss_D: 0.62955, user_f1: 0.60194, asser_f1: 0.91798
# Epoch: 197, loss_recon: 0.59064, loss_kl: 0.00000, loss_tc: 0.00100, loss_VAE: 0.59164, loss_D: 0.68171, user_f1: 0.60194, asser_f1: 0.92118
# Epoch: 198, loss_recon: 0.59055, loss_kl: 0.00000, loss_tc: 0.00023, loss_VAE: 0.59078, loss_D: 0.62139, user_f1: 0.60194, asser_f1: 0.58187
# Epoch: 199, loss_recon: 0.59057, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.59063, loss_D: 0.63928, user_f1: 0.60194, asser_f1: 0.58062
# Epoch: 200, loss_recon: 0.59023, loss_kl: 0.00000, loss_tc: 0.00034, loss_VAE: 0.59057, loss_D: 0.62422, user_f1: 0.60194, asser_f1: 0.58560
# Epoch: 201, loss_recon: 0.59010, loss_kl: 0.00000, loss_tc: 0.00042, loss_VAE: 0.59052, loss_D: 0.63617, user_f1: 0.60194, asser_f1: 0.57181
# Epoch: 202, loss_recon: 0.58992, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.59009, loss_D: 0.63057, user_f1: 0.60194, asser_f1: 0.57984
# Epoch: 203, loss_recon: 0.58976, loss_kl: 0.00000, loss_tc: 0.00018, loss_VAE: 0.58994, loss_D: 0.63182, user_f1: 0.60194, asser_f1: 0.57693
# Epoch: 204, loss_recon: 0.58968, loss_kl: 0.00000, loss_tc: 0.00027, loss_VAE: 0.58995, loss_D: 0.63337, user_f1: 0.60194, asser_f1: 0.58066
# Epoch: 205, loss_recon: 0.58937, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.58954, loss_D: 0.63345, user_f1: 0.60194, asser_f1: 0.58314
# Epoch: 206, loss_recon: 0.58921, loss_kl: 0.00000, loss_tc: 0.00023, loss_VAE: 0.58944, loss_D: 0.63270, user_f1: 0.60194, asser_f1: 0.58766
# Epoch: 207, loss_recon: 0.58916, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.58936, loss_D: 0.63592, user_f1: 0.60194, asser_f1: 0.58561
# Epoch: 208, loss_recon: 0.58893, loss_kl: 0.00000, loss_tc: 0.00021, loss_VAE: 0.58914, loss_D: 0.63416, user_f1: 0.60194, asser_f1: 0.59417
# Epoch: 209, loss_recon: 0.58877, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.58892, loss_D: 0.63939, user_f1: 0.60194, asser_f1: 0.59296
# Epoch: 210, loss_recon: 0.58861, loss_kl: 0.00000, loss_tc: 0.00036, loss_VAE: 0.58897, loss_D: 0.64764, user_f1: 0.60194, asser_f1: 0.59051
# Epoch: 211, loss_recon: 0.58841, loss_kl: 0.00000, loss_tc: -0.00006, loss_VAE: 0.58835, loss_D: 0.64491, user_f1: 0.60194, asser_f1: 0.59092
# Epoch: 212, loss_recon: 0.58831, loss_kl: 0.00000, loss_tc: 0.00054, loss_VAE: 0.58885, loss_D: 0.65966, user_f1: 0.60194, asser_f1: 0.60103
# Epoch: 213, loss_recon: 0.58796, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.58799, loss_D: 0.64465, user_f1: 0.60194, asser_f1: 0.59579
# Epoch: 214, loss_recon: 0.58782, loss_kl: 0.00000, loss_tc: 0.00024, loss_VAE: 0.58807, loss_D: 0.64729, user_f1: 0.60194, asser_f1: 0.59943
# Epoch: 215, loss_recon: 0.58762, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.58779, loss_D: 0.64479, user_f1: 0.60194, asser_f1: 0.59781
# Epoch: 216, loss_recon: 0.58734, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.58747, loss_D: 0.64203, user_f1: 0.60194, asser_f1: 0.60184
# Epoch: 217, loss_recon: 0.58722, loss_kl: 0.00000, loss_tc: 0.00029, loss_VAE: 0.58751, loss_D: 0.64139, user_f1: 0.60194, asser_f1: 0.60023
# Epoch: 218, loss_recon: 0.58701, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.58709, loss_D: 0.64572, user_f1: 0.60194, asser_f1: 0.60224
# Epoch: 219, loss_recon: 0.58687, loss_kl: 0.00000, loss_tc: 0.00030, loss_VAE: 0.58717, loss_D: 0.64837, user_f1: 0.60194, asser_f1: 0.60344
# Epoch: 220, loss_recon: 0.58653, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.58655, loss_D: 0.64721, user_f1: 0.59740, asser_f1: 0.60464
# Epoch: 221, loss_recon: 0.58655, loss_kl: 0.00000, loss_tc: 0.00047, loss_VAE: 0.58701, loss_D: 0.66005, user_f1: 0.59740, asser_f1: 0.60304
# Epoch: 222, loss_recon: 0.58639, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.58637, loss_D: 0.65188, user_f1: 0.59740, asser_f1: 0.60184
# Epoch: 223, loss_recon: 0.58607, loss_kl: 0.00000, loss_tc: 0.00032, loss_VAE: 0.58639, loss_D: 0.65180, user_f1: 0.59740, asser_f1: 0.60384
# Epoch: 224, loss_recon: 0.58587, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.58601, loss_D: 0.64861, user_f1: 0.59740, asser_f1: 0.60023
# Epoch: 225, loss_recon: 0.58573, loss_kl: 0.00000, loss_tc: 0.00009, loss_VAE: 0.58582, loss_D: 0.64863, user_f1: 0.59740, asser_f1: 0.60023
# Epoch: 226, loss_recon: 0.58558, loss_kl: 0.00000, loss_tc: 0.00030, loss_VAE: 0.58588, loss_D: 0.64901, user_f1: 0.59740, asser_f1: 0.60143
# Epoch: 227, loss_recon: 0.58531, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.58540, loss_D: 0.65170, user_f1: 0.59283, asser_f1: 0.60063
# Epoch: 228, loss_recon: 0.58518, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.58532, loss_D: 0.65071, user_f1: 0.59283, asser_f1: 0.60184
# Epoch: 229, loss_recon: 0.58485, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.58505, loss_D: 0.64781, user_f1: 0.57895, asser_f1: 0.59902
# Epoch: 230, loss_recon: 0.58454, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.58466, loss_D: 0.65439, user_f1: 0.58824, asser_f1: 0.60224
# Epoch: 231, loss_recon: 0.58438, loss_kl: 0.00000, loss_tc: 0.00027, loss_VAE: 0.58465, loss_D: 0.65540, user_f1: 0.58361, asser_f1: 0.59862
# Epoch: 232, loss_recon: 0.58409, loss_kl: 0.00000, loss_tc: -0.00007, loss_VAE: 0.58402, loss_D: 0.66289, user_f1: 0.58824, asser_f1: 0.59701
# Epoch: 233, loss_recon: 0.58386, loss_kl: 0.00000, loss_tc: 0.00065, loss_VAE: 0.58451, loss_D: 0.68745, user_f1: 0.58824, asser_f1: 0.59701
# Epoch: 234, loss_recon: 0.58340, loss_kl: 0.00000, loss_tc: 0.00005, loss_VAE: 0.58345, loss_D: 0.65941, user_f1: 0.58824, asser_f1: 0.59902
# Epoch: 235, loss_recon: 0.58306, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.58313, loss_D: 0.66331, user_f1: 0.58824, asser_f1: 0.59822
# Epoch: 236, loss_recon: 0.58288, loss_kl: 0.00000, loss_tc: 0.00024, loss_VAE: 0.58313, loss_D: 0.65323, user_f1: 0.58824, asser_f1: 0.59781
# Epoch: 237, loss_recon: 0.58259, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.58275, loss_D: 0.65603, user_f1: 0.58824, asser_f1: 0.59579
# Epoch: 238, loss_recon: 0.58238, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.58254, loss_D: 0.65445, user_f1: 0.58824, asser_f1: 0.59741
# Epoch: 239, loss_recon: 0.58206, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.58223, loss_D: 0.65357, user_f1: 0.58361, asser_f1: 0.59822
# Epoch: 240, loss_recon: 0.58199, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.58212, loss_D: 0.65297, user_f1: 0.58361, asser_f1: 0.59620
# Epoch: 241, loss_recon: 0.58174, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.58189, loss_D: 0.65423, user_f1: 0.58361, asser_f1: 0.59377
# Epoch: 242, loss_recon: 0.58148, loss_kl: 0.00000, loss_tc: 0.00018, loss_VAE: 0.58166, loss_D: 0.65616, user_f1: 0.58361, asser_f1: 0.59660
# Epoch: 243, loss_recon: 0.58126, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.58130, loss_D: 0.65794, user_f1: 0.57895, asser_f1: 0.59701
# Epoch: 244, loss_recon: 0.58103, loss_kl: 0.00000, loss_tc: 0.00038, loss_VAE: 0.58140, loss_D: 0.66635, user_f1: 0.57895, asser_f1: 0.59417
# Epoch: 245, loss_recon: 0.58088, loss_kl: 0.00000, loss_tc: -0.00016, loss_VAE: 0.58072, loss_D: 0.67020, user_f1: 0.57895, asser_f1: 0.59498
# Epoch: 246, loss_recon: 0.58054, loss_kl: 0.00000, loss_tc: 0.00048, loss_VAE: 0.58102, loss_D: 0.67562, user_f1: 0.57895, asser_f1: 0.59620
# Epoch: 247, loss_recon: 0.58033, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.58043, loss_D: 0.65743, user_f1: 0.57895, asser_f1: 0.59377
# Epoch: 248, loss_recon: 0.58005, loss_kl: 0.00000, loss_tc: 0.00003, loss_VAE: 0.58008, loss_D: 0.65859, user_f1: 0.57895, asser_f1: 0.59377
# Epoch: 249, loss_recon: 0.57982, loss_kl: 0.00000, loss_tc: 0.00026, loss_VAE: 0.58008, loss_D: 0.65982, user_f1: 0.57895, asser_f1: 0.58929
# Epoch: 250, loss_recon: 0.57958, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.57969, loss_D: 0.66113, user_f1: 0.57895, asser_f1: 0.59051
# Epoch: 251, loss_recon: 0.57934, loss_kl: 0.00000, loss_tc: 0.00012, loss_VAE: 0.57945, loss_D: 0.66006, user_f1: 0.57895, asser_f1: 0.59011
# Epoch: 252, loss_recon: 0.57918, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.57932, loss_D: 0.66044, user_f1: 0.57426, asser_f1: 0.59092
# Epoch: 253, loss_recon: 0.57892, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.57903, loss_D: 0.65729, user_f1: 0.56954, asser_f1: 0.58929
# Epoch: 254, loss_recon: 0.57879, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.57897, loss_D: 0.65745, user_f1: 0.56954, asser_f1: 0.59214
# Epoch: 255, loss_recon: 0.57863, loss_kl: 0.00000, loss_tc: 0.00002, loss_VAE: 0.57865, loss_D: 0.66137, user_f1: 0.56954, asser_f1: 0.58970
# Epoch: 256, loss_recon: 0.57849, loss_kl: 0.00000, loss_tc: 0.00034, loss_VAE: 0.57883, loss_D: 0.66711, user_f1: 0.56954, asser_f1: 0.58806
# Epoch: 257, loss_recon: 0.57842, loss_kl: 0.00000, loss_tc: -0.00012, loss_VAE: 0.57830, loss_D: 0.66686, user_f1: 0.56954, asser_f1: 0.59011
# Epoch: 258, loss_recon: 0.57831, loss_kl: 0.00000, loss_tc: 0.00035, loss_VAE: 0.57866, loss_D: 0.67009, user_f1: 0.56478, asser_f1: 0.58725
# Epoch: 259, loss_recon: 0.57817, loss_kl: 0.00000, loss_tc: -0.00003, loss_VAE: 0.57814, loss_D: 0.67007, user_f1: 0.56478, asser_f1: 0.58520
# Epoch: 260, loss_recon: 0.57817, loss_kl: 0.00000, loss_tc: 0.00030, loss_VAE: 0.57847, loss_D: 0.67715, user_f1: 0.56478, asser_f1: 0.58684
# Epoch: 261, loss_recon: 0.57807, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.57811, loss_D: 0.66460, user_f1: 0.56478, asser_f1: 0.58520
# Epoch: 262, loss_recon: 0.57804, loss_kl: 0.00000, loss_tc: 0.00015, loss_VAE: 0.57820, loss_D: 0.66483, user_f1: 0.56478, asser_f1: 0.58520
# Epoch: 263, loss_recon: 0.57800, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.57817, loss_D: 0.66077, user_f1: 0.56478, asser_f1: 0.58602
# Epoch: 264, loss_recon: 0.57806, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.57816, loss_D: 0.66379, user_f1: 0.56478, asser_f1: 0.58561
# Epoch: 265, loss_recon: 0.57804, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.57815, loss_D: 0.66307, user_f1: 0.55518, asser_f1: 0.58684
# Epoch: 266, loss_recon: 0.57802, loss_kl: 0.00000, loss_tc: 0.00017, loss_VAE: 0.57818, loss_D: 0.66406, user_f1: 0.56000, asser_f1: 0.58396
# Epoch: 267, loss_recon: 0.57803, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.57811, loss_D: 0.66220, user_f1: 0.55518, asser_f1: 0.58561
# Epoch: 268, loss_recon: 0.57791, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.57806, loss_D: 0.66158, user_f1: 0.55518, asser_f1: 0.58479
# Epoch: 269, loss_recon: 0.57794, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.57803, loss_D: 0.66424, user_f1: 0.55518, asser_f1: 0.58643
# Epoch: 270, loss_recon: 0.57806, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.57815, loss_D: 0.66254, user_f1: 0.55518, asser_f1: 0.58479
# Epoch: 271, loss_recon: 0.57800, loss_kl: 0.00000, loss_tc: 0.00020, loss_VAE: 0.57820, loss_D: 0.66327, user_f1: 0.55518, asser_f1: 0.58314
# Epoch: 272, loss_recon: 0.57800, loss_kl: 0.00000, loss_tc: -0.00009, loss_VAE: 0.57791, loss_D: 0.67069, user_f1: 0.55518, asser_f1: 0.58396
# Epoch: 273, loss_recon: 0.57810, loss_kl: 0.00000, loss_tc: 0.00057, loss_VAE: 0.57867, loss_D: 0.69148, user_f1: 0.55518, asser_f1: 0.58273
# Epoch: 274, loss_recon: 0.57814, loss_kl: 0.00000, loss_tc: -0.00021, loss_VAE: 0.57793, loss_D: 0.68529, user_f1: 0.55518, asser_f1: 0.58273
# Epoch: 275, loss_recon: 0.57793, loss_kl: 0.00000, loss_tc: 0.00023, loss_VAE: 0.57816, loss_D: 0.67185, user_f1: 0.55518, asser_f1: 0.58190
# Epoch: 276, loss_recon: 0.57801, loss_kl: 0.00000, loss_tc: 0.00027, loss_VAE: 0.57828, loss_D: 0.66379, user_f1: 0.55518, asser_f1: 0.58314
# Epoch: 277, loss_recon: 0.57805, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.57811, loss_D: 0.66706, user_f1: 0.55518, asser_f1: 0.58066
# Epoch: 278, loss_recon: 0.57803, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.57813, loss_D: 0.66556, user_f1: 0.55518, asser_f1: 0.58149
# Epoch: 279, loss_recon: 0.57801, loss_kl: 0.00000, loss_tc: 0.00019, loss_VAE: 0.57820, loss_D: 0.66476, user_f1: 0.55518, asser_f1: 0.57859
# Epoch: 280, loss_recon: 0.57819, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.57830, loss_D: 0.66113, user_f1: 0.55518, asser_f1: 0.57942
# Epoch: 281, loss_recon: 0.57815, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.57826, loss_D: 0.66195, user_f1: 0.55518, asser_f1: 0.57901
# Epoch: 282, loss_recon: 0.57806, loss_kl: 0.00000, loss_tc: 0.00016, loss_VAE: 0.57822, loss_D: 0.66247, user_f1: 0.55518, asser_f1: 0.57984
# Epoch: 283, loss_recon: 0.57822, loss_kl: 0.00000, loss_tc: 0.00007, loss_VAE: 0.57829, loss_D: 0.66388, user_f1: 0.56000, asser_f1: 0.57984
# Epoch: 284, loss_recon: 0.57821, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.57836, loss_D: 0.66417, user_f1: 0.56000, asser_f1: 0.58190
# Epoch: 285, loss_recon: 0.57816, loss_kl: 0.00000, loss_tc: 0.00006, loss_VAE: 0.57822, loss_D: 0.66503, user_f1: 0.56000, asser_f1: 0.57735
# Epoch: 286, loss_recon: 0.57823, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.57844, loss_D: 0.66965, user_f1: 0.56000, asser_f1: 0.57693
# Epoch: 287, loss_recon: 0.57831, loss_kl: 0.00000, loss_tc: -0.00012, loss_VAE: 0.57819, loss_D: 0.68542, user_f1: 0.56000, asser_f1: 0.57818
# Epoch: 288, loss_recon: 0.57838, loss_kl: 0.00000, loss_tc: 0.00043, loss_VAE: 0.57881, loss_D: 0.68126, user_f1: 0.56000, asser_f1: 0.58025
# Epoch: 289, loss_recon: 0.57840, loss_kl: 0.00000, loss_tc: -0.00002, loss_VAE: 0.57838, loss_D: 0.66762, user_f1: 0.56000, asser_f1: 0.57735
# Epoch: 290, loss_recon: 0.57843, loss_kl: 0.00000, loss_tc: 0.00022, loss_VAE: 0.57865, loss_D: 0.67316, user_f1: 0.56000, asser_f1: 0.57859
# Epoch: 291, loss_recon: 0.57850, loss_kl: 0.00000, loss_tc: 0.00008, loss_VAE: 0.57858, loss_D: 0.66783, user_f1: 0.56000, asser_f1: 0.57610
# Epoch: 292, loss_recon: 0.57846, loss_kl: 0.00000, loss_tc: 0.00011, loss_VAE: 0.57857, loss_D: 0.67012, user_f1: 0.56000, asser_f1: 0.57693
# Epoch: 293, loss_recon: 0.57854, loss_kl: 0.00000, loss_tc: 0.00014, loss_VAE: 0.57867, loss_D: 0.66299, user_f1: 0.56000, asser_f1: 0.57527
# Epoch: 294, loss_recon: 0.57862, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.57872, loss_D: 0.66741, user_f1: 0.56478, asser_f1: 0.57735
# Epoch: 295, loss_recon: 0.57853, loss_kl: 0.00000, loss_tc: 0.00010, loss_VAE: 0.57863, loss_D: 0.66388, user_f1: 0.56000, asser_f1: 0.57444
# Epoch: 296, loss_recon: 0.57865, loss_kl: 0.00000, loss_tc: 0.00013, loss_VAE: 0.57879, loss_D: 0.66573, user_f1: 0.56000, asser_f1: 0.57735
# Epoch: 297, loss_recon: 0.57883, loss_kl: 0.00000, loss_tc: 0.00004, loss_VAE: 0.57888, loss_D: 0.66425, user_f1: 0.56000, asser_f1: 0.57693
# Epoch: 298, loss_recon: 0.57878, loss_kl: 0.00000, loss_tc: 0.00023, loss_VAE: 0.57900, loss_D: 0.67053, user_f1: 0.56000, asser_f1: 0.57402
# Epoch: 299, loss_recon: 0.57887, loss_kl: 0.00000, loss_tc: -0.00014, loss_VAE: 0.57873, loss_D: 0.67962, user_f1: 0.56000, asser_f1: 0.57485
# Embedding and dependencies are saved in ./output
# Running Evaluation ...

# %%
accs = []
fs = []

for i in range(len(seeds)):
    acc = metrics.accuracy_score(truth[i], res[i])
    _, _, f, _ = metrics.precision_recall_fscore_support(truth[i], res[i], average='weighted')
    accs.append(acc)
    fs.append(f)

acc_m = mean(accs)
f_m = mean(fs)
if len(accs) > 1:
    acc_st = stdev(accs)
    f_st = stdev(fs)
    print("Mean Accuracy :", round(acc_m, 4) * 100, "\tSt. dev :", round(acc_st, 4) * 100)
    print("Mean Weighted F1 :", round(f_m, 4) * 100, "\tSt. dev :", round(f_st, 4) * 100)
else:
    print("Accuracy :", round(acc_m, 4) * 100)
    print("Weighted F1 :", round(f_m, 4) * 100)
# Out:
# Mean Accuracy : 70.49 	St. dev : 1.76
# Mean Weighted F1 : 67.69 	St. dev : 2.3
